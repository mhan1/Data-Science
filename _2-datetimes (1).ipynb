# %% [markdown]
# # DateTimes

# %% [markdown]
# ### Introduction

# %% [markdown]
# Deciding which features should be included and focused on in our linear model is an important skill of any data scientist.  As we saw previously, if we include features which are too collinear, we will improperly measure the coefficients related to our collinear features.  In addition, feature selection and prioritizing features with feature importance will help us to understand which features to devote our attention to in terms of feature engineering and domain understanding.  Finally, limiting the number of features in our model, and identifying the most crucial features in our model will make our models, and their insights more understandable.

# %% [markdown]
# ### Working with AirBnb

# %% [markdown]
# For this lesson, we'll work with [AirBnb listings in Berlin](https://www.kaggle.com/brittabettendorf/berlin-airbnb-data).

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/mhan1/Data-Science/master/listings_summary.csv')

# %%
df.shape
# Out:
# (22552, 96)

# %% [markdown]
# As we can see, our dataset as 22,500 rows and close to 100 features.  Our goal is to predict the price.

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# Some of these columns include data that we do not know how to handle - mainly textual data and images.  A lot of this data is simply not in the correct format.  Let's take a look.

# %%
pd.set_option('display.max_rows',100)

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# id                              22552.0  1.571560e+07  8.552069e+06
# scrape_id                       22552.0  2.018111e+13  4.812607e+00
# thumbnail_url                       0.0           NaN           NaN
# medium_url                          0.0           NaN           NaN
# xl_picture_url                      0.0           NaN           NaN
# host_id                         22552.0  5.403355e+07  5.816290e+07
# host_acceptance_rate                0.0           NaN           NaN
# host_listings_count             22526.0  2.330685e+00  1.994782e+01
# host_total_listings_count       22526.0  2.330685e+00  1.994782e+01
# latitude                        22552.0  5.250982e+01  3.082546e-02
# longitude                       22552.0  1.340611e+01  5.796365e-02
# accommodates                    22552.0  2.637460e+00  1.510548e+00
# bathrooms                       22520.0  1.092695e+00  3.298943e-01
# bedrooms                        22534.0  1.161134e+00  6.461559e-01
# beds                            22512.0  1.620558e+00  1.174840e+00
# square_feet                       446.0  4.654013e+02  5.034919e+02
# guests_included                 22552.0  1.332121e+00  8.350343e-01
# minimum_nights                  22552.0  7.157059e+00  4.066507e+01
# maximum_nights                  22552.0  1.030505e+05  9.640519e+06
# availability_30                 22552.0  4.944173e+00  8.677395e+00
# availability_60                 22552.0  1.114664e+01  1.752237e+01
# availability_90                 22552.0  2.001610e+01  2.834914e+01
# availability_365                22552.0  7.985283e+01  1.193682e+02
# number_of_reviews               22552.0  1.784068e+01  3.676962e+01
# review_scores_rating            18163.0  9.441386e+01  7.639644e+00
# review_scores_accuracy          18138.0  9.663965e+00  7.400390e-01
# review_scores_cleanliness       18141.0  9.324955e+00  1.031996e+00
# review_scores_checkin           18120.0  9.713521e+00  7.046199e-01
# review_scores_communication     18134.0  9.730672e+00  6.866140e-01
# review_scores_location          18121.0  9.505491e+00  7.621606e-01
# review_scores_value             18117.0  9.411106e+00  8.414916e-01
# jurisdiction_names                  0.0           NaN           NaN
# calculated_host_listings_count  22552.0  1.918233e+00  3.667257e+00
# reviews_per_month               18638.0  1.135525e+00  1.507082e+00
#
#                                          min           25%           50%  \
# id                              2.015000e+03  8.065954e+06  1.686638e+07
# scrape_id                       2.018111e+13  2.018111e+13  2.018111e+13
# thumbnail_url                            NaN           NaN           NaN
# medium_url                               NaN           NaN           NaN
# xl_picture_url                           NaN           NaN           NaN
# host_id                         2.217000e+03  9.240002e+06  3.126711e+07
# host_acceptance_rate                     NaN           NaN           NaN
# host_listings_count             0.000000e+00  1.000000e+00  1.000000e+00
# host_total_listings_count       0.000000e+00  1.000000e+00  1.000000e+00
# latitude                        5.234580e+01  5.248906e+01  5.250908e+01
# longitude                       1.310356e+01  1.337541e+01  1.341678e+01
# accommodates                    1.000000e+00  2.000000e+00  2.000000e+00
# bathrooms                       0.000000e+00  1.000000e+00  1.000000e+00
# bedrooms                        0.000000e+00  1.000000e+00  1.000000e+00
# beds                            0.000000e+00  1.000000e+00  1.000000e+00
# square_feet                     0.000000e+00  0.000000e+00  4.035000e+02
# guests_included                 1.000000e+00  1.000000e+00  1.000000e+00
# minimum_nights                  1.000000e+00  2.000000e+00  2.000000e+00
# maximum_nights                  1.000000e+00  2.000000e+01  1.124000e+03
# availability_30                 0.000000e+00  0.000000e+00  0.000000e+00
# availability_60                 0.000000e+00  0.000000e+00  0.000000e+00
# availability_90                 0.000000e+00  0.000000e+00  0.000000e+00
# availability_365                0.000000e+00  0.000000e+00  4.000000e+00
# number_of_reviews               0.000000e+00  1.000000e+00  5.000000e+00
# review_scores_rating            2.000000e+01  9.200000e+01  9.700000e+01
# review_scores_accuracy          2.000000e+00  1.000000e+01  1.000000e+01
# review_scores_cleanliness       2.000000e+00  9.000000e+00  1.000000e+01
# review_scores_checkin           2.000000e+00  1.000000e+01  1.000000e+01
# review_scores_communication     2.000000e+00  1.000000e+01  1.000000e+01
# review_scores_location          2.000000e+00  9.000000e+00  1.000000e+01
# review_scores_value             2.000000e+00  9.000000e+00  1.000000e+01
# jurisdiction_names                       NaN           NaN           NaN
# calculated_host_listings_count  1.000000e+00  1.000000e+00  1.000000e+00
# reviews_per_month               1.000000e-02  1.800000e-01  5.400000e-01
#
#                                          75%           max
# id                              2.258393e+07  2.986735e+07
# scrape_id                       2.018111e+13  2.018111e+13
# thumbnail_url                            NaN           NaN
# medium_url                               NaN           NaN
# xl_picture_url                           NaN           NaN
# host_id                         8.067518e+07  2.245081e+08
# host_acceptance_rate                     NaN           NaN
# host_listings_count             2.000000e+00  1.676000e+03
# host_total_listings_count       2.000000e+00  1.676000e+03
# latitude                        5.253267e+01  5.265167e+01
# longitude                       1.343926e+01  1.375764e+01
# accommodates                    3.000000e+00  1.600000e+01
# bathrooms                       1.000000e+00  8.500000e+00
# bedrooms                        1.000000e+00  1.200000e+01
# beds                            2.000000e+00  2.200000e+01
# square_feet                     7.075000e+02  4.639000e+03
# guests_included                 1.000000e+00  1.600000e+01
# minimum_nights                  4.000000e+00  5.000000e+03
# maximum_nights                  1.125000e+03  1.000000e+09
# availability_30                 6.000000e+00  3.000000e+01
# availability_60                 1.800000e+01  6.000000e+01
# availability_90                 3.600000e+01  9.000000e+01
# availability_365                1.290000e+02  3.650000e+02
# number_of_reviews               1.600000e+01  4.980000e+02
# review_scores_rating            1.000000e+02  1.000000e+02
# review_scores_accuracy          1.000000e+01  1.000000e+01
# review_scores_cleanliness       1.000000e+01  1.000000e+01
# review_scores_checkin           1.000000e+01  1.000000e+01
# review_scores_communication     1.000000e+01  1.000000e+01
# review_scores_location          1.000000e+01  1.000000e+01
# review_scores_value             1.000000e+01  1.000000e+01
# jurisdiction_names                       NaN           NaN
# calculated_host_listings_count  1.000000e+00  4.500000e+01
# reviews_per_month               1.500000e+00  3.667000e+01

# %% [markdown]
# A lot of the data is listed as objects, which is really a catch all.

# %%
df.dtypes
# Out:
# id                                    int64
# listing_url                          object
# scrape_id                             int64
# last_scraped                         object
# name                                 object
# summary                              object
# space                                object
# description                          object
# experiences_offered                  object
# neighborhood_overview                object
# notes                                object
# transit                              object
# access                               object
# interaction                          object
# house_rules                          object
# thumbnail_url                       float64
# medium_url                          float64
# picture_url                          object
# xl_picture_url                      float64
# host_id                               int64
# host_url                             object
# host_name                            object
# host_since                           object
# host_location                        object
# host_about                           object
# host_response_time                   object
# host_response_rate                   object
# host_acceptance_rate                float64
# host_is_superhost                    object
# host_thumbnail_url                   object
# host_picture_url                     object
# host_neighbourhood                   object
# host_listings_count                 float64
# host_total_listings_count           float64
# host_verifications                   object
# host_has_profile_pic                 object
# host_identity_verified               object
# street                               object
# neighbourhood                        object
# neighbourhood_cleansed               object
# neighbourhood_group_cleansed         object
# city                                 object
# state                                object
# zipcode                              object
# market                               object
# smart_location                       object
# country_code                         object
# country                              object
# latitude                            float64
# longitude                           float64
# is_location_exact                    object
# property_type                        object
# room_type                            object
# accommodates                          int64
# bathrooms                           float64
# bedrooms                            float64
# beds                                float64
# bed_type                             object
# amenities                            object
# square_feet                         float64
# price                                object
# weekly_price                         object
# monthly_price                        object
# security_deposit                     object
# cleaning_fee                         object
# guests_included                       int64
# extra_people                         object
# minimum_nights                        int64
# maximum_nights                        int64
# calendar_updated                     object
# has_availability                     object
# availability_30                       int64
# availability_60                       int64
# availability_90                       int64
# availability_365                      int64
# calendar_last_scraped                object
# number_of_reviews                     int64
# first_review                         object
# last_review                          object
# review_scores_rating                float64
# review_scores_accuracy              float64
# review_scores_cleanliness           float64
# review_scores_checkin               float64
# review_scores_communication         float64
# review_scores_location              float64
# review_scores_value                 float64
# requires_license                     object
# license                              object
# jurisdiction_names                  float64
# instant_bookable                     object
# is_business_travel_ready             object
# cancellation_policy                  object
# require_guest_profile_picture        object
# require_guest_phone_verification     object
# calculated_host_listings_count        int64
# reviews_per_month                   float64
# dtype: object

# %%
df.dtypes[10:15]
# Out:
# notes          object
# transit        object
# access         object
# interaction    object
# house_rules    object
# dtype: object

# %%
def find_object_features(df):
    return list(df.dtypes[df.dtypes == 'object'].index)

# %%
find_object_features(df)
# Out:
# ['listing_url',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'picture_url',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'bed_type',
#  'amenities',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'extra_people',
#  'calendar_updated',
#  'has_availability',
#  'calendar_last_scraped',
#  'first_review',
#  'last_review',
#  'requires_license',
#  'license',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification']

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# listing_url                         object
# last_scraped                        object
# name                                object
# summary                             object
# space                               object
# description                         object
# experiences_offered                 object
# neighborhood_overview               object
# notes                               object
# transit                             object
# access                              object
# interaction                         object
# house_rules                         object
# picture_url                         object
# host_url                            object
# host_name                           object
# host_since                          object
# host_location                       object
# host_about                          object
# host_response_time                  object
# host_response_rate                  object
# host_is_superhost                   object
# host_thumbnail_url                  object
# host_picture_url                    object
# host_neighbourhood                  object
# host_verifications                  object
# host_has_profile_pic                object
# host_identity_verified              object
# street                              object
# neighbourhood                       object
# neighbourhood_cleansed              object
# neighbourhood_group_cleansed        object
# city                                object
# state                               object
# zipcode                             object
# market                              object
# smart_location                      object
# country_code                        object
# country                             object
# is_location_exact                   object
# property_type                       object
# room_type                           object
# bed_type                            object
# amenities                           object
# price                               object
# weekly_price                        object
# monthly_price                       object
# security_deposit                    object
# cleaning_fee                        object
# extra_people                        object
# calendar_updated                    object
# has_availability                    object
# calendar_last_scraped               object
# first_review                        object
# last_review                         object
# requires_license                    object
# license                             object
# instant_bookable                    object
# is_business_travel_ready            object
# cancellation_policy                 object
# require_guest_profile_picture       object
# require_guest_phone_verification    object
# dtype: object

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# Let's try to capture as much of this object data as possible.  In this lesson, we'll start with date values.

# %%
def find_object_feature_values(df):
    object_features = find_object_features(df)
    return df[object_features][:2].values

# %%
find_object_feature_values(df)
# Out:
# array([['https://www.airbnb.com/rooms/2015', '2018-11-07',
#         'Berlin-Mitte Value! Quiet courtyard/very central',
#         'Great location!  30 of 75 sq meters. This wood floored/high ceiling typical Berlin "Altbau" section of an apartment consists of 1 simple large room, a small kitchen and a bathroom + shower. The apartment is in Mitte, close to Prenzlauer Berg/Mauerpark. Perfect for short visits, singles or couples. Your section is closed from the rest of the bigger flat wich is not noticeable. You will not be sharing your space.',
#         'A+++ location! This „Einliegerwohnung“ is an extention of a larger apartment with a separate entrance, bathroom and kitchen. The door to the rest of the apartment is soundproof, hidden, locked and barely noticable (behind mirror in pictures). Your 30 sq meters are facing a quiet courtyard. This wood floored/high ceiling typical Berlin "Altbau" apartment consists of 1 large room with a large double bed, optionally with an extra matress for a 3rd guest), a small kitchen suitable for preparing simple meals, a bathroom + shower + bathtub and of course your own entrance (all linens and towels are provided.) it is located facing a quiet courtyard, it is clean cozy and an authentic "Berlin" place to live. The place is in Mitte, close to Prenzlauer Berg one block from Kastanienallee, Zionskirchplatz, Rosenthaler Platz and Mauerpark. Generally this area is lively with galleries, museums, resturants, cafes, flea markets, bars, clubs, shops, good take away food, a park, U-Bahn, trams, supermarket',
#         'Great location!  30 of 75 sq meters. This wood floored/high ceiling typical Berlin "Altbau" section of an apartment consists of 1 simple large room, a small kitchen and a bathroom + shower. The apartment is in Mitte, close to Prenzlauer Berg/Mauerpark. Perfect for short visits, singles or couples. Your section is closed from the rest of the bigger flat wich is not noticeable. You will not be sharing your space. A+++ location! This „Einliegerwohnung“ is an extention of a larger apartment with a separate entrance, bathroom and kitchen. The door to the rest of the apartment is soundproof, hidden, locked and barely noticable (behind mirror in pictures). Your 30 sq meters are facing a quiet courtyard. This wood floored/high ceiling typical Berlin "Altbau" apartment consists of 1 large room with a large double bed, optionally with an extra matress for a 3rd guest), a small kitchen suitable for preparing simple meals, a bathroom + shower + bathtub and of course your own entrance (all linens a',
#         'none',
#         'It is located in the former East Berlin area of Kastanienallee and Zionskirchplatz (Berlins only natural elevation), very charming and original turn of the last century architecture; this area was barely been destroyed during the war. Close to galleries, resturants, museums, flea markets, cafes, bars, clubs, shops, good take away food, a park, great public transportation: U-Bahn, S-Bahn, Trams, Busses, supermarkets etc.',
#         'This is my home, not a hotel. I rent out occasionally when I stay with my friend.',
#         'Close to U-Bahn U8 and U2 (metro), Trams M12, M10 and M8, Busses. Rosenthaler Platz and Hackescher Markt are close by. S-Bahn. Alexander Platz is 6 minutes away on the U8 line.',
#         'Simple kitchen/cooking, refrigerator, microwave oven, stove, dishwasher, espresso/ coffee mashine, cable TV deskspace, shower, bath tub, little courtyard garden, 1st floor. There is a large double bed and optional additional airbeds for a 3rd or 4th person/kids. (Please note that the apartment is 30 square meters, if you stay a few nights and are more than 2 adults, it will be tight)',
#         'Always available',
#         'No parties No events No pets No smoking, not even in the courtyard/garden Do not pull the door shut with the keys in the lock from the inside; should that happen, the guest pays for locksmith',
#         'https://a0.muscache.com/im/pictures/260fd609-710a-4304-82ab-abd7498efd62.jpg?aki_policy=large',
#         'https://www.airbnb.com/users/show/2217', 'Ian', '2008-08-18',
#         'Key Biscayne, Florida, United States',
#         'Believe in sharing economy.', 'within an hour', '96%', 't',
#         'https://a0.muscache.com/im/pictures/21428a22-4f38-444d-8c72-5892be9da109.jpg?aki_policy=profile_small',
#         'https://a0.muscache.com/im/pictures/21428a22-4f38-444d-8c72-5892be9da109.jpg?aki_policy=profile_x_medium',
#         'Mitte',
#         "['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'government_id']",
#         't', 't', 'Berlin, Berlin, Germany', 'Mitte', 'Brunnenstr. Süd',
#         'Mitte', 'Berlin', 'Berlin', '10119', 'Berlin',
#         'Berlin, Germany', 'DE', 'Germany', 'f', 'Guesthouse',
#         'Entire home/apt', 'Real Bed',
#         '{TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Family/kid friendly","Smoke detector",Essentials,Shampoo,"Lock on bedroom door",Hangers,"Hair dryer",Iron,"Laptop friendly workspace","Private living room",Bathtub,"Hot water","Bed linens","Extra pillows and blankets",Microwave,"Coffee maker",Refrigerator,Dishwasher,"Dishes and silverware","Cooking basics",Stove,"Luggage dropoff allowed","Long term stays allowed"}',
#         '$60.00', nan, nan, '$200.00', '$30.00', '$28.00',
#         '3 months ago', 't', '2018-11-07', '2016-04-11', '2018-10-28',
#         't', nan, 'f', 'f', 'strict_14_with_grace_period', 'f', 'f'],
#        ['https://www.airbnb.com/rooms/2695', '2018-11-07',
#         'Prenzlauer Berg close to Mauerpark', nan,
#         "In the summertime we are spending most of our weekends in our little house in our garden and want to use the opportunity to rent a room in our cosy 2 bedroom apartment. But we might also stay in the other room. We will be very happy to give you tips on things to do and see in Berlin and make sure your stay runs smoothly. The room is about 25 square meters and is located on the 2nd floor. The bed measures 180 cm x 200 cm and is fitted with a kapok futon, which is a hard-ish mattress but which we find very pleasant to sleep on.  It's a typical Berlin-style apartment located in a friendly and calm neighborhood, plus your room is facing away from the street and into the interior area (so generally very quiet).  All the cafes, bars, shops and other action of the Prenzlauerberg district is easily accessible with a pleasant 10-15 minute stroll across Mauerpark. The main S-Bahn and U-Bahn public transport connections are also just a 10-15 minute walk away. There are all sorts of options for ea",
#         "In the summertime we are spending most of our weekends in our little house in our garden and want to use the opportunity to rent a room in our cosy 2 bedroom apartment. But we might also stay in the other room. We will be very happy to give you tips on things to do and see in Berlin and make sure your stay runs smoothly. The room is about 25 square meters and is located on the 2nd floor. The bed measures 180 cm x 200 cm and is fitted with a kapok futon, which is a hard-ish mattress but which we find very pleasant to sleep on.  It's a typical Berlin-style apartment located in a friendly and calm neighborhood, plus your room is facing away from the street and into the interior area (so generally very quiet).  All the cafes, bars, shops and other action of the Prenzlauerberg district is easily accessible with a pleasant 10-15 minute stroll across Mauerpark. The main S-Bahn and U-Bahn public transport connections are also just a 10-15 minute walk away. There are all sorts of options for ea",
#         'none', nan, nan,
#         "Within walking distance you'll find the S-Bahn, two metro lines,  tram lines and busses.  But the best way to discover Berlin is by bike. Please ask if you need a guest bike.",
#         'Außer deinem Zimmer kannst du noch die Küche und das Badezimmer benutzen. Es gibt auch einen Balkon, den man tagsüber benutzen kann. Der Zugang führt allerdings durch unser anderes Zimmer, wo wir dann abends eventuel schlafen.',
#         nan, nan,
#         'https://a0.muscache.com/im/pictures/97d4f6e8-1c77-47fc-958e-26ba5618083c.jpg?aki_policy=large',
#         'https://www.airbnb.com/users/show/2986', 'Michael',
#         '2008-09-16', 'Berlin, Berlin, Germany',
#         'Living with my wife in Berlin.  Like travelling, hiking, canoing, beach volleyball, yoga, cinema....',
#         nan, nan, 'f',
#         'https://a0.muscache.com/im/pictures/50434955-1888-4049-bbff-a78464dbfa5a.jpg?aki_policy=profile_small',
#         'https://a0.muscache.com/im/pictures/50434955-1888-4049-bbff-a78464dbfa5a.jpg?aki_policy=profile_x_medium',
#         'Prenzlauer Berg',
#         "['email', 'phone', 'reviews', 'jumio', 'government_id']", 't',
#         't', 'Berlin, Berlin, Germany', nan, 'Prenzlauer Berg Nordwest',
#         'Pankow', 'Berlin', 'Berlin', '10437', 'Berlin',
#         'Berlin, Germany', 'DE', 'Germany', 't', 'Apartment',
#         'Private room', 'Real Bed',
#         '{Wifi,Kitchen,Elevator,Heating,Washer,Essentials,Shampoo,"Hair dryer","Laptop friendly workspace","Private living room"}',
#         '$17.00', nan, nan, '$0.00', '$0.00', '$0.00', '7 weeks ago',
#         't', '2018-11-07', '2018-07-04', '2018-10-01', 't', nan, 'f',
#         'f', 'flexible', 'f', 'f']], dtype=object)

# %%
find_object_feature_values(df)[0, :3]
# Out:
# array(['https://www.airbnb.com/rooms/2015', '2018-11-07',
#        'Berlin-Mitte Value! Quiet courtyard/very central'], dtype=object)

# %% [markdown]
# We can see that the second column, `last_scraped` should be a date, but is listed as an object.  It would be nice if we could use the `to_datetime` method to put our columns in the correct format.

# %%
pd.to_datetime(df['last_scraped'], infer_datetime_format=True)
# Out:
# 0       2018-11-07
# 1       2018-11-07
# 2       2018-11-07
# 3       2018-11-07
# 4       2018-11-07
# 5       2018-11-07
# 6       2018-11-07
# 7       2018-11-07
# 8       2018-11-07
# 9       2018-11-07
# 10      2018-11-07
# 11      2018-11-07
# 12      2018-11-07
# 13      2018-11-07
# 14      2018-11-07
# 15      2018-11-07
# 16      2018-11-07
# 17      2018-11-07
# 18      2018-11-07
# 19      2018-11-07
# 20      2018-11-07
# 21      2018-11-07
# 22      2018-11-07
# 23      2018-11-07
# 24      2018-11-07
# 25      2018-11-07
# 26      2018-11-07
# 27      2018-11-07
# 28      2018-11-07
# 29      2018-11-07
# 30      2018-11-07
# 31      2018-11-07
# 32      2018-11-07
# 33      2018-11-07
# 34      2018-11-07
# 35      2018-11-07
# 36      2018-11-07
# 37      2018-11-07
# 38      2018-11-07
# 39      2018-11-07
# 40      2018-11-07
# 41      2018-11-07
# 42      2018-11-07
# 43      2018-11-07
# 44      2018-11-07
# 45      2018-11-07
# 46      2018-11-07
# 47      2018-11-07
# 48      2018-11-07
# 49      2018-11-07
#            ...
# 22502   2018-11-07
# 22503   2018-11-07
# 22504   2018-11-07
# 22505   2018-11-07
# 22506   2018-11-07
# 22507   2018-11-07
# 22508   2018-11-07
# 22509   2018-11-07
# 22510   2018-11-07
# 22511   2018-11-07
# 22512   2018-11-07
# 22513   2018-11-07
# 22514   2018-11-07
# 22515   2018-11-07
# 22516   2018-11-07
# 22517   2018-11-07
# 22518   2018-11-07
# 22519   2018-11-07
# 22520   2018-11-07
# 22521   2018-11-07
# 22522   2018-11-07
# 22523   2018-11-07
# 22524   2018-11-07
# 22525   2018-11-07
# 22526   2018-11-07
# 22527   2018-11-07
# 22528   2018-11-07
# 22529   2018-11-07
# 22530   2018-11-07
# 22531   2018-11-07
# 22532   2018-11-07
# 22533   2018-11-07
# 22534   2018-11-07
# 22535   2018-11-07
# 22536   2018-11-07
# 22537   2018-11-07
# 22538   2018-11-07
# 22539   2018-11-07
# 22540   2018-11-07
# 22541   2018-11-07
# 22542   2018-11-07
# 22543   2018-11-07
# 22544   2018-11-07
# 22545   2018-11-07
# 22546   2018-11-07
# 22547   2018-11-07
# 22548   2018-11-07
# 22549   2018-11-07
# 22550   2018-11-07
# 22551   2018-11-07
# Name: last_scraped, Length: 22552, dtype: datetime64[ns]

# %% [markdown]
# But it doesn't work as well as we would hope. Let's write a method called `is_date` that detects if our column value is a date.

# %%
def contains_date(column):
#     remove nas first, potentially use all
    regex_string = (r'^\d{1,2}-\d{1,2}-\d{4}$|^\d{4}-\d{1,2}-\d{1,2}$' + 
'|^\d{1,2}\/\d{1,2}\/\d{4}$|^\d{4}\/\d{1,2}\/\d{1,2}$')
    return column.str.contains(regex_string).any()

# %% [markdown]
# The regex above is wild but it's easier to understand once we understand that each `|` means `or`.  So really, we can think of the above regex as multiple different ones.  So the first one of them is:
#
# `^\d{1,2}-\d{1,2}-\d{4}$`

# %% [markdown]
# Which means start with one or two digits, then one or two digits again, and then four digits.  With each set of digits separated by a hyphen.
#
# `11-22-2018`

# %% [markdown]
# So contains date tells us if any column in the above contains a date.

# %%
contains_date(df.last_scraped)
# Out:
# True

# %%
contains_date(df.host_since)
# Out:
# True

# %%
contains_date(df.house_rules)
# Out:
# False

# %%
def find_date_features(df):
    series_contains_date = df.apply(contains_date)
    return series_contains_date.index[series_contains_date.values]

# %%
find_date_features(df)
# Out:
# Index(['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review',
#        'last_review'],
#       dtype='object')

# %%
date_features = find_date_features(df)

# %%
date_features
# Out:
# Index(['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review',
#        'last_review'],
#       dtype='object')

# %% [markdown]
# Now we can set those features to be date time.

# %%
def to_dates(df):
    date_features = find_date_features(df)
    return df[date_features].astype('datetime64[ns]')

# %%
df_date_features = to_dates(df)

# %%
df_date_features
# Out:
#       last_scraped host_since calendar_last_scraped first_review last_review
# 0       2018-11-07 2008-08-18            2018-11-07   2016-04-11  2018-10-28
# 1       2018-11-07 2008-09-16            2018-11-07   2018-07-04  2018-10-01
# 2       2018-11-07 2008-10-19            2018-11-07   2009-06-20  2017-03-20
# 3       2018-11-07 2008-11-07            2018-11-07   2013-08-12  2018-08-16
# 4       2018-11-07 2009-05-16            2018-11-07   2009-08-18  2018-11-04
# 5       2018-11-07 2009-08-25            2018-11-07   2015-08-09  2018-07-23
# 6       2018-11-07 2009-11-18            2018-11-07   2010-06-29  2018-11-01
# 7       2018-11-07 2009-12-03            2018-11-07          NaT         NaT
# 8       2018-11-07 2009-12-20            2018-11-07   2010-06-04  2017-12-14
# 9       2018-11-07 2010-01-04            2018-11-07   2010-10-07  2018-10-31
# 10      2018-11-07 2010-01-08            2018-11-07   2010-02-18  2018-10-30
# 22545   2018-11-07 2018-01-02            2018-11-07          NaT         NaT
# 22546   2018-11-07 2014-09-15            2018-11-07          NaT         NaT
# 22547   2018-11-07 2016-08-02            2018-11-07          NaT         NaT
# 22548   2018-11-07 2016-04-17            2018-11-07          NaT         NaT
# 22549   2018-11-07 2012-08-03            2018-11-07          NaT         NaT
# 22550   2018-11-07 2015-06-28            2018-11-07          NaT         NaT
# 22551   2018-11-07 2018-03-09            2018-11-07          NaT         NaT
#
# [22552 rows x 5 columns]

# %%
df_date_features.dtypes
# Out:
# last_scraped             datetime64[ns]
# host_since               datetime64[ns]
# calendar_last_scraped    datetime64[ns]
# first_review             datetime64[ns]
# last_review              datetime64[ns]
# dtype: object

# %%
df_date_features.dtypes

# last_scraped             datetime64[ns]
# host_since               datetime64[ns]
# calendar_last_scraped    datetime64[ns]
# first_review             datetime64[ns]
# last_review              datetime64[ns]

df_date_features[:3]
# Out:
#   last_scraped host_since calendar_last_scraped first_review last_review
# 0   2018-11-07 2008-08-18            2018-11-07   2016-04-11  2018-10-28
# 1   2018-11-07 2008-09-16            2018-11-07   2018-07-04  2018-10-01
# 2   2018-11-07 2008-10-19            2018-11-07   2009-06-20  2017-03-20

# %%
# make it work
# make it right
# make it fast

# %%
from date_lib import add_datepart

# %%
copied_df = df.copy()
add_datepart(copied_df, 'last_scraped')

# %%
# 1. periodic data
# 2. external data
#     * weather
# 3. differences within a row or differences between rows
# first listing

# %%
copied_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        ...
#        'last_scrapedDay', 'last_scrapedDayofweek', 'last_scrapedDayofyear',
#        'last_scrapedIs_month_end', 'last_scrapedIs_month_start',
#        'last_scrapedIs_quarter_end', 'last_scrapedIs_quarter_start',
#        'last_scrapedIs_year_end', 'last_scrapedIs_year_start',
#        'last_scrapedElapsed'],
#       dtype='object', length=108)

# %%
len(copied_df.columns)
# Out:
# 108

# %%
len(df.columns)
# Out:
# 96

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
copied_df.head(2)
# Out:
#      id                        listing_url       scrape_id  \
# 0  2015  https://www.airbnb.com/rooms/2015  20181107122246
# 1  2695  https://www.airbnb.com/rooms/2695  20181107122246
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
# 1  In the summertime we are spending most of our ...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
# 1  In the summertime we are spending most of our ...                none
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
#
#                                                notes         ...          \
# 0  This is my home, not a hotel. I rent out occas...         ...
# 1                                                NaN         ...
#
#   last_scrapedDay last_scrapedDayofweek last_scrapedDayofyear  \
# 0               7                     2                   311
# 1               7                     2                   311
#
#   last_scrapedIs_month_end  last_scrapedIs_month_start  \
# 0                    False                       False
# 1                    False                       False
#
#    last_scrapedIs_quarter_end last_scrapedIs_quarter_start  \
# 0                       False                        False
# 1                       False                        False
#
#    last_scrapedIs_year_end  last_scrapedIs_year_start last_scrapedElapsed
# 0                    False                      False          1541548800
# 1                    False                      False          1541548800
#
# [2 rows x 108 columns]

# %%
df.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2015  https://www.airbnb.com/rooms/2015  20181107122246   2018-11-07
# 1  2695  https://www.airbnb.com/rooms/2695  20181107122246   2018-11-07
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
# 1  In the summertime we are spending most of our ...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
# 1  In the summertime we are spending most of our ...                none
#
#                                neighborhood_overview        ...          \
# 0  It is located in the former East Berlin area o...        ...
# 1                                                NaN        ...
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                t     NaN                NaN                f
# 1                t     NaN                NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               4               3.76
# 1                               1               1.42
#
# [2 rows x 96 columns]

# %%
def generate_new_date_columns(dates_df):
    copied_dates_df = dates_df.copy()
    for col in copied_dates_df.columns:
        add_datepart(copied_dates_df, col)
    return copied_dates_df

# %%
generate_new_date_columns(df_date_features)
# Out:
#        last_scrapedYear  last_scrapedMonth  last_scrapedWeek  last_scrapedDay  \
# 0                  2018                 11                45                7
# 1                  2018                 11                45                7
# 2                  2018                 11                45                7
# 3                  2018                 11                45                7
# 4                  2018                 11                45                7
# 5                  2018                 11                45                7
# 6                  2018                 11                45                7
# 7                  2018                 11                45                7
# 8                  2018                 11                45                7
# 9                  2018                 11                45                7
# 10                 2018                 11                45                7
# 11                 2018                 11                45                7
# 12                 2018                 11                45                7
# 13                 2018                 11                45                7
# 14                 2018                 11                45                7
# 15                 2018                 11                45                7
# 16                 2018                 11                45                7
# 17                 2018                 11                45                7
# 18                 2018                 11                45                7
# 19                 2018                 11                45                7
# 20                 2018                 11                45                7
# 21                 2018                 11                45                7
# 22                 2018                 11                45                7
# 23                 2018                 11                45                7
# 24                 2018                 11                45                7
# 25                 2018                 11                45                7
# 26                 2018                 11                45                7
# 27                 2018                 11                45                7
# 28                 2018                 11                45                7
# 29                 2018                 11                45                7
# 30                 2018                 11                45                7
# 31                 2018                 11                45                7
# 32                 2018                 11                45                7
# 33                 2018                 11                45                7
# 34                 2018                 11                45                7
# 35                 2018                 11                45                7
# 36                 2018                 11                45                7
# 39                         2                    311                     False
# 40                         2                    311                     False
# 41                         2                    311                     False
# 42                         2                    311                     False
# 43                         2                    311                     False
# 44                         2                    311                     False
# 45                         2                    311                     False
# 46                         2                    311                     False
# 47                         2                    311                     False
# 48                         2                    311                     False
# 49                         2                    311                     False
# ...                      ...                    ...                       ...
# 22502                      2                    311                     False
# 22503                      2                    311                     False
# 22504                      2                    311                     False
# 22505                      2                    311                     False
# 22506                      2                    311                     False
# 22507                      2                    311                     False
# 22508                      2                    311                     False
# 22509                      2                    311                     False
# 22510                      2                    311                     False
# 22511                      2                    311                     False
# 22512                      2                    311                     False
# 22513                      2                    311                     False
# 22514                      2                    311                     False
# 22515                      2                    311                     False
# 22516                      2                    311                     False
# 22517                      2                    311                     False
# 22518                      2                    311                     False
# 22519                      2                    311                     False
# 22520                      2                    311                     False
# 22521                      2                    311                     False
# 22522                      2                    311                     False
# 22523                      2                    311                     False
# 22524                      2                    311                     False
# 22525                      2                    311                     False
# 22526                      2                    311                     False
# 22527                      2                    311                     False
# 22528                      2                    311                     False
# 22529                      2                    311                     False
# 22530                      2                    311                     False
# 22531                      2                    311                     False
# 22532                      2                    311                     False
# 22533                      2                    311                     False
# 22534                      2                    311                     False
# 22535                      2                    311                     False
# 22536                      2                    311                     False
# 22537                      2                    311                     False
# 22538                      2                    311                     False
# 22539                      2                    311                     False
# 22540                      2                    311                     False
# 22541                      2                    311                     False
# 22542                      2                    311                     False
# 22543                      2                    311                     False
# 22544                      2                    311                     False
# 22545                      2                    311                     False
# 22546                      2                    311                     False
# 22547                      2                    311                     False
# 22548                      2                    311                     False
# 22549                      2                    311                     False
# 22550                      2                    311                     False
# 22551                      2                    311                     False
#
#        last_scrapedIs_month_start  last_scrapedIs_quarter_end  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# 5                           False                       False
# 6                           False                       False
# 7                           False                       False
# 8                           False                       False
# 9                           False                       False
# 10                          False                       False
# 11                          False                       False
# 12                          False                       False
# 13                          False                       False
# 14                          False                       False
# 15                          False                       False
# 16                          False                       False
# 17                          False                       False
# 18                          False                       False
# 19                          False                       False
# 20                          False                       False
# 21                          False                       False
# 22                          False                       False
# 23                          False                       False
# 24                          False                       False
# 25                          False                       False
# 26                          False                       False
# 27                          False                       False
# 28                          False                       False
# 29                          False                       False
# 30                          False                       False
# 31                          False                       False
# 32                          False                       False
# 33                          False                       False
# 34                          False                       False
# 35                          False                       False
# 36                          False                       False
# 37                          False                       False
# 38                          False                       False
# 39                          False                       False
# 40                          False                       False
# 41                          False                       False
# 42                          False                       False
# 43                          False                       False
# 44                          False                       False
# 45                          False                       False
# 46                          False                       False
# 47                          False                       False
# 48                          False                       False
# 49                          False                       False
# ...                           ...                         ...
# 22502                       False                       False
# 22503                       False                       False
# 22504                       False                       False
# 22505                       False                       False
# 22506                       False                       False
# 22507                       False                       False
# 22508                       False                       False
# 22509                       False                       False
# 22510                       False                       False
# 22511                       False                       False
# 22512                       False                       False
# 22513                       False                       False
# 22514                       False                       False
# 22515                       False                       False
# 22516                       False                       False
# 22517                       False                       False
# 22518                       False                       False
# 22519                       False                       False
# 22520                       False                       False
# 22521                       False                       False
# 22522                       False                       False
# 22523                       False                       False
# 22524                       False                       False
# 22525                       False                       False
# 22526                       False                       False
# 22527                       False                       False
# 22528                       False                       False
# 22529                       False                       False
# 22530                       False                       False
# 22531                       False                       False
# 22532                       False                       False
# 22533                       False                       False
# 22534                       False                       False
# 22535                       False                       False
# 22536                       False                       False
# 22537                       False                       False
# 22538                       False                       False
# 22539                       False                       False
# 22540                       False                       False
# 22541                       False                       False
# 22542                       False                       False
# 22543                       False                       False
# 22544                       False                       False
# 22545                       False                       False
# 22546                       False                       False
# 22547                       False                       False
# 22548                       False                       False
# 22549                       False                       False
# 22550                       False                       False
# 22551                       False                       False
#
#        last_scrapedIs_quarter_start         ...          last_reviewDay  \
# 0                             False         ...                    28.0
# 1                             False         ...                     1.0
# 2                             False         ...                    20.0
# 3                             False         ...                    16.0
# 4                             False         ...                     4.0
# 5                             False         ...                    23.0
# 6                             False         ...                     1.0
# 7                             False         ...                     NaN
# 8                             False         ...                    14.0
# 9                             False         ...                    31.0
# 10                            False         ...                    30.0
# 11                            False         ...                    20.0
# 12                            False         ...                     5.0
# 13                            False         ...                     1.0
# 14                            False         ...                     5.0
# 15                            False         ...                    30.0
# 16                            False         ...                    25.0
# 17                            False         ...                    14.0
# 18                            False         ...                     5.0
# 19                            False         ...                    29.0
# 20                            False         ...                     2.0
# 21                            False         ...                    13.0
# 22                            False         ...                    31.0
# 23                            False         ...                    31.0
# 24                            False         ...                    28.0
# 25                            False         ...                     4.0
# 26                            False         ...                    16.0
# 27                            False         ...                    19.0
# 28                            False         ...                    25.0
# 29                            False         ...                     4.0
# 30                            False         ...                    30.0
# 31                            False         ...                    21.0
# 32                            False         ...                    27.0
# 33                            False         ...                    26.0
# 34                            False         ...                     8.0
# 35                            False         ...                    26.0
# 36                            False         ...                     1.0
# 37                            False         ...                     4.0
# 38                            False         ...                    31.0
# 39                            False         ...                     1.0
# 40                            False         ...                     9.0
# 41                            False         ...                    11.0
# 42                            False         ...                    29.0
# 43                            False         ...                    29.0
# 44                            False         ...                     NaN
# 45                            False         ...                    21.0
# 46                            False         ...                    14.0
# 47                            False         ...                     NaN
# 48                            False         ...                    26.0
# 49                            False         ...                    12.0
# ...                             ...         ...                     ...
# 22502                         False         ...                     NaN
# 22503                         False         ...                     NaN
# 22504                         False         ...                     NaN
# 22505                         False         ...                     NaN
# 22506                         False         ...                     NaN
# 22507                         False         ...                     NaN
# 22508                         False         ...                     7.0
# 22509                         False         ...                     NaN
# 22510                         False         ...                     NaN
# 22511                         False         ...                     NaN
# 22512                         False         ...                     NaN
# 22513                         False         ...                     NaN
# 22514                         False         ...                     NaN
# 22515                         False         ...                     NaN
# 22516                         False         ...                     NaN
# 22517                         False         ...                     NaN
# 22518                         False         ...                     NaN
# 22519                         False         ...                     NaN
# 22520                         False         ...                     NaN
# 22521                         False         ...                     NaN
# 22524                      False                      False
# 22525                      False                      False
# 22526                      False                      False
# 22527                      False                      False
# 22528                      False                      False
# 22529                      False                      False
# 22530                      False                      False
# 22531                      False                      False
# 22532                      False                      False
# 22533                      False                      False
# 22534                      False                      False
# 22535                      False                      False
# 22536                      False                      False
# 22537                      False                      False
# 22538                      False                      False
# 22539                      False                      False
# 22540                      False                      False
# 22541                      False                      False
# 22542                      False                      False
# 22543                      False                      False
# 22544                      False                      False
# 22545                      False                      False
# 22546                      False                      False
# 22547                      False                      False
# 22548                      False                      False
# 22549                      False                      False
# 22550                      False                      False
# 22551                      False                      False
#
#        last_reviewIs_quarter_start  last_reviewIs_year_end  \
# 0                            False                   False
# 1                             True                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# 5                            False                   False
# 6                            False                   False
# 7                            False                   False
# 8                            False                   False
# 9                            False                   False
# 10                           False                   False
# 11                           False                   False
# 12                           False                   False
# 13                            True                   False
# 14                           False                   False
# 15                           False                   False
# 16                           False                   False
# 17                           False                   False
# 18                           False                   False
# 19                           False                   False
# 20                           False                   False
# 21                           False                   False
# 22                           False                   False
# 23                           False                   False
# 24                           False                   False
# 25                           False                   False
# 26                           False                   False
# 27                           False                   False
# 28                           False                   False
# 29                           False                   False
# 30                           False                   False
# 31                           False                   False
# 32                           False                   False
# 33                           False                   False
# 34                           False                   False
# 35                           False                   False
# 36                            True                   False
# 37                           False                   False
# 38                           False                   False
# 39                            True                   False
# 40                           False                   False
# 41                           False                   False
# 42                           False                   False
# 43                           False                   False
# 44                           False                   False
# 45                           False                   False
# 46                           False                   False
# 47                           False                   False
# 48                           False                   False
# 49                           False                   False
# ...                            ...                     ...
# 22502                        False                   False
# 22503                        False                   False
# 22504                        False                   False
# 22505                        False                   False
# 22506                        False                   False
# 22507                        False                   False
# 22508                        False                   False
# 22509                        False                   False
# 22510                        False                   False
# 22511                        False                   False
# 22512                        False                   False
# 22513                        False                   False
# 22514                        False                   False
# 22515                        False                   False
# 22516                        False                   False
# 22517                        False                   False
# 22518                        False                   False
# 22519                        False                   False
# 22520                        False                   False
# 22521                        False                   False
# 22522                        False                   False
# 22523                        False                   False
# 22524                        False                   False
# 22525                        False                   False
# 22526                        False                   False
# 22527                        False                   False
# 22528                        False                   False
# 22529                        False                   False
# 22530                        False                   False
# 22531                        False                   False
# 22532                        False                   False
# 22533                        False                   False
# 22534                        False                   False
# 22535                        False                   False
# 22536                        False                   False
# 22537                        False                   False
# 22538                        False                   False
# 22539                        False                   False
# 22540                        False                   False
# 22541                        False                   False
# 22542                        False                   False
# 22543                        False                   False
# 22544                        False                   False
# 22545                        False                   False
# 22546                        False                   False
# 22547                        False                   False
# 22548                        False                   False
# 22549                        False                   False
# 22550                        False                   False
# 22551                        False                   False
#
#        last_reviewIs_year_start  last_reviewElapsed
# 0                         False          1540684800
# 1                         False          1538352000
# 2                         False          1489968000
# 3                         False          1534377600
# 4                         False          1541289600
# 5                         False          1532304000
# 6                         False          1541030400
# 7                         False         -9223372037
# 8                         False          1513209600
# 9                         False          1540944000
# 10                        False          1540857600
# 11                        False          1539993600
# 12                        False          1465084800
# 13                        False          1538352000
# 14                        False          1541376000
# 15                        False          1530316800
# 16                        False          1535155200
# 17                        False          1471132800
# 18                        False          1541376000
# 19                        False          1493424000
# 20                        False          1501632000
# 21                        False          1376352000
# 22                        False          1532995200
# 23                        False          1540944000
# 24                        False          1540684800
# 25                        False          1541289600
# 26                        False          1284595200
# 27                        False          1539907200
# 28                        False          1537833600
# 29                        False          1538611200
# 30                        False          1540857600
# 31                        False          1532131200
# 32                        False          1343347200
# 33                        False          1474848000
# 34                        False          1507420800
# 35                        False          1411689600
# 36                        False          1538352000
# 37                        False          1541289600
# 38                        False          1540944000
# 39                        False          1538352000
# 40                        False          1539043200
# 41                        False          1520726400
# 42                        False          1535500800
# 43                        False          1538179200
# 44                        False         -9223372037
# 45                        False          1477008000
# 46                        False          1539475200
# 47                        False         -9223372037
# 48                        False          1296000000
# 49                        False          1457740800
# ...                         ...                 ...
# 22502                     False         -9223372037
# 22503                     False         -9223372037
# 22504                     False         -9223372037
# 22505                     False         -9223372037
# 22506                     False         -9223372037
# 22507                     False         -9223372037
# 22508                     False          1541548800
# 22509                     False         -9223372037
# 22510                     False         -9223372037
# 22511                     False         -9223372037
# 22512                     False         -9223372037
# 22513                     False         -9223372037
# 22514                     False         -9223372037
# 22515                     False         -9223372037
# 22516                     False         -9223372037
# 22517                     False         -9223372037
# 22518                     False         -9223372037
# 22519                     False         -9223372037
# 22520                     False         -9223372037
# 22521                     False         -9223372037
# 22522                     False         -9223372037
# 22523                     False         -9223372037
# 22524                     False         -9223372037
# 22525                     False         -9223372037
# 22526                     False         -9223372037
# 22527                     False         -9223372037
# 22528                     False         -9223372037
# 22529                     False         -9223372037
# 22530                     False         -9223372037
# 22531                     False         -9223372037
# 22532                     False         -9223372037
# 22533                     False         -9223372037
# 22534                     False         -9223372037
# 22535                     False         -9223372037
# 22536                     False          1541548800
# 22537                     False         -9223372037
# 22538                     False         -9223372037
# 22539                     False         -9223372037
# 22540                     False         -9223372037
# 22541                     False         -9223372037
# 22542                     False         -9223372037
# 22543                     False         -9223372037
# 22544                     False         -9223372037
# 22545                     False         -9223372037
# 22546                     False         -9223372037
# 22547                     False         -9223372037
# 22548                     False         -9223372037
# 22549                     False         -9223372037
# 22550                     False         -9223372037
# 22551                     False         -9223372037
#
# [22552 rows x 65 columns]

# %%
new_date_col_df = generate_new_date_columns(df_date_features)

# %%
len(new_date_col_df.columns)
# Out:
# 65

# %%
len(df_date_features.columns)
# Out:
# 5

# %%
new_date_col_df.columns
# Out:
# Index(['last_scrapedYear', 'last_scrapedMonth', 'last_scrapedWeek',
#        'last_scrapedDay', 'last_scrapedDayofweek', 'last_scrapedDayofyear',
#        'last_scrapedIs_month_end', 'last_scrapedIs_month_start',
#        'last_scrapedIs_quarter_end', 'last_scrapedIs_quarter_start',
#        'last_scrapedIs_year_end', 'last_scrapedIs_year_start',
#        'last_scrapedElapsed', 'host_sinceYear', 'host_sinceMonth',
#        'host_sinceWeek', 'host_sinceDay', 'host_sinceDayofweek',
#        'host_sinceDayofyear', 'host_sinceIs_month_end',
#        'host_sinceIs_month_start', 'host_sinceIs_quarter_end',
#        'host_sinceIs_quarter_start', 'host_sinceIs_year_end',
#        'host_sinceIs_year_start', 'host_sinceElapsed',
#        'calendar_last_scrapedYear', 'calendar_last_scrapedMonth',
#        'calendar_last_scrapedWeek', 'calendar_last_scrapedDay',
#        'calendar_last_scrapedDayofweek', 'calendar_last_scrapedDayofyear',
#        'calendar_last_scrapedIs_month_end',
#        'calendar_last_scrapedIs_month_start',
#        'calendar_last_scrapedIs_quarter_end',
#        'calendar_last_scrapedIs_quarter_start',
#        'calendar_last_scrapedIs_year_end',
#        'calendar_last_scrapedIs_year_start', 'calendar_last_scrapedElapsed',
#        'first_reviewYear', 'first_reviewMonth', 'first_reviewWeek',
#        'first_reviewDay', 'first_reviewDayofweek', 'first_reviewDayofyear',
#        'first_reviewIs_month_end', 'first_reviewIs_month_start',
#        'first_reviewIs_quarter_end', 'first_reviewIs_quarter_start',
#        'first_reviewIs_year_end', 'first_reviewIs_year_start',
#        'first_reviewElapsed', 'last_reviewYear', 'last_reviewMonth',
#        'last_reviewWeek', 'last_reviewDay', 'last_reviewDayofweek',
#        'last_reviewDayofyear', 'last_reviewIs_month_end',
#        'last_reviewIs_month_start', 'last_reviewIs_quarter_end',
#        'last_reviewIs_quarter_start', 'last_reviewIs_year_end',
#        'last_reviewIs_year_start', 'last_reviewElapsed'],
#       dtype='object')

# %%
df_date_features.columns
# Out:
# Index(['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review',
#        'last_review'],
#       dtype='object')

# %% [markdown]
# Once coercing our dates, we can merge with the original dataframe, and replace each of the old columns that should be dates.

# %%
def merge_dfs(original_df, new_df):
    copied_original = original_df.copy()
    date_features = find_date_features(original_df)
    copied_dropped = copied_original.drop(columns = date_features)
    copied_dropped[new_df.columns] = new_df
    return copied_dropped

# %%
merge_dfs(df, new_date_col_df).head(2).T
# Out:
#                                                                                        0  \
# id                                                                                  2015
# listing_url                                            https://www.airbnb.com/rooms/2015
# scrape_id                                                                 20181107122246
# name                                    Berlin-Mitte Value! Quiet courtyard/very central
# summary                                Great location!  30 of 75 sq meters. This wood...
# space                                  A+++ location! This „Einliegerwohnung“ is an e...
# description                            Great location!  30 of 75 sq meters. This wood...
# experiences_offered                                                                 none
# neighborhood_overview                  It is located in the former East Berlin area o...
# notes                                  This is my home, not a hotel. I rent out occas...
# transit                                Close to U-Bahn U8 and U2 (metro), Trams M12, ...
# access                                 Simple kitchen/cooking, refrigerator, microwav...
# interaction                                                             Always available
# house_rules                            No parties No events No pets No smoking, not e...
# thumbnail_url                                                                        NaN
# medium_url                                                                           NaN
# picture_url                            https://a0.muscache.com/im/pictures/260fd609-7...
# xl_picture_url                                                                       NaN
# host_id                                                                             2217
# host_url                                          https://www.airbnb.com/users/show/2217
# host_name                                                                            Ian
# host_location                                       Key Biscayne, Florida, United States
# host_about                                                   Believe in sharing economy.
# host_response_time                                                        within an hour
# host_response_rate                                                                   96%
# host_acceptance_rate                                                                 NaN
# host_is_superhost                                                                      t
# host_thumbnail_url                     https://a0.muscache.com/im/pictures/21428a22-4...
# host_picture_url                       https://a0.muscache.com/im/pictures/21428a22-4...
# host_neighbourhood                                                                 Mitte
# host_listings_count                                                                    4
# host_total_listings_count                                                              4
# host_verifications                     ['email', 'phone', 'reviews', 'jumio', 'offlin...
# host_has_profile_pic                                                                   t
# host_identity_verified                                                                 t
# street                                                           Berlin, Berlin, Germany
# neighbourhood                                                                      Mitte
# neighbourhood_cleansed                                                   Brunnenstr. Süd
# neighbourhood_group_cleansed                                                       Mitte
# city                                                                              Berlin
# state                                                                             Berlin
# zipcode                                                                            10119
# market                                                                            Berlin
# smart_location                                                           Berlin, Germany
# country_code                                                                          DE
# country                                                                          Germany
# latitude                                                                         52.5345
# longitude                                                                        13.4026
# is_location_exact                                                                      f
# property_type                                                                 Guesthouse
# ...                                                                                  ...
# host_sinceWeek                                                                        34
# host_sinceDay                                                                         18
# host_sinceDayofweek                                                                    0
# host_sinceDayofyear                                                                  231
# host_sinceIs_month_end                                                             False
# host_sinceIs_month_start                                                           False
# host_sinceIs_quarter_end                                                           False
# host_sinceIs_quarter_start                                                         False
# host_sinceIs_year_end                                                              False
# host_sinceIs_year_start                                                            False
# host_sinceElapsed                                                             1219017600
# calendar_last_scrapedYear                                                           2018
# calendar_last_scrapedMonth                                                            11
# calendar_last_scrapedWeek                                                             45
# calendar_last_scrapedDay                                                               7
# calendar_last_scrapedDayofweek                                                         2
# calendar_last_scrapedDayofyear                                                       311
# calendar_last_scrapedIs_month_end                                                  False
# calendar_last_scrapedIs_month_start                                                False
# calendar_last_scrapedIs_quarter_end                                                False
# calendar_last_scrapedIs_quarter_start                                              False
# calendar_last_scrapedIs_year_end                                                   False
# calendar_last_scrapedIs_year_start                                                 False
# calendar_last_scrapedElapsed                                                  1541548800
# first_reviewYear                                                                    2016
# first_reviewMonth                                                                      4
# first_reviewWeek                                                                      15
# first_reviewDay                                                                       11
# first_reviewDayofweek                                                                  0
# first_reviewDayofyear                                                                102
# first_reviewIs_month_end                                                           False
# first_reviewIs_month_start                                                         False
# first_reviewIs_quarter_end                                                         False
# first_reviewIs_quarter_start                                                       False
# first_reviewIs_year_end                                                            False
# first_reviewIs_year_start                                                          False
# first_reviewElapsed                                                           1460332800
# last_reviewYear                                                                     2018
# last_reviewMonth                                                                      10
# last_reviewWeek                                                                       43
# last_reviewDay                                                                        28
# last_reviewDayofweek                                                                   6
# last_reviewDayofyear                                                                 301
# last_reviewIs_month_end                                                            False
# last_reviewIs_month_start                                                          False
# last_reviewIs_quarter_end                                                          False
# last_reviewIs_quarter_start                                                        False
# last_reviewIs_year_end                                                             False
# last_reviewIs_year_start                                                           False
# last_reviewElapsed                                                            1540684800
#
#                                                                                        1
# id                                                                                  2695
# listing_url                                            https://www.airbnb.com/rooms/2695
# scrape_id                                                                 20181107122246
# name                                                  Prenzlauer Berg close to Mauerpark
# summary                                                                              NaN
# space                                  In the summertime we are spending most of our ...
# description                            In the summertime we are spending most of our ...
# experiences_offered                                                                 none
# neighborhood_overview                                                                NaN
# notes                                                                                NaN
# transit                                Within walking distance you'll find the S-Bahn...
# access                                 Außer deinem Zimmer kannst du noch die Küche u...
# interaction                                                                          NaN
# house_rules                                                                          NaN
# thumbnail_url                                                                        NaN
# medium_url                                                                           NaN
# picture_url                            https://a0.muscache.com/im/pictures/97d4f6e8-1...
# xl_picture_url                                                                       NaN
# host_id                                                                             2986
# host_url                                          https://www.airbnb.com/users/show/2986
# host_name                                                                        Michael
# host_location                                                    Berlin, Berlin, Germany
# host_about                             Living with my wife in Berlin.  Like travellin...
# host_response_time                                                                   NaN
# host_response_rate                                                                   NaN
# host_acceptance_rate                                                                 NaN
# host_is_superhost                                                                      f
# host_thumbnail_url                     https://a0.muscache.com/im/pictures/50434955-1...
# host_picture_url                       https://a0.muscache.com/im/pictures/50434955-1...
# host_neighbourhood                                                       Prenzlauer Berg
# host_listings_count                                                                    1
# host_total_listings_count                                                              1
# host_verifications                     ['email', 'phone', 'reviews', 'jumio', 'govern...
# host_has_profile_pic                                                                   t
# host_identity_verified                                                                 t
# street                                                           Berlin, Berlin, Germany
# neighbourhood                                                                        NaN
# neighbourhood_cleansed                                          Prenzlauer Berg Nordwest
# neighbourhood_group_cleansed                                                      Pankow
# city                                                                              Berlin
# state                                                                             Berlin
# zipcode                                                                            10437
# market                                                                            Berlin
# smart_location                                                           Berlin, Germany
# country_code                                                                          DE
# country                                                                          Germany
# latitude                                                                         52.5485
# longitude                                                                        13.4046
# is_location_exact                                                                      t
# property_type                                                                  Apartment
# ...                                                                                  ...
# host_sinceWeek                                                                        38
# host_sinceDay                                                                         16
# host_sinceDayofweek                                                                    1
# host_sinceDayofyear                                                                  260
# host_sinceIs_month_end                                                             False
# host_sinceIs_month_start                                                           False
# host_sinceIs_quarter_end                                                           False
# host_sinceIs_quarter_start                                                         False
# host_sinceIs_year_end                                                              False
# host_sinceIs_year_start                                                            False
# host_sinceElapsed                                                             1221523200
# calendar_last_scrapedYear                                                           2018
# calendar_last_scrapedMonth                                                            11
# calendar_last_scrapedWeek                                                             45
# calendar_last_scrapedDay                                                               7
# calendar_last_scrapedDayofweek                                                         2
# calendar_last_scrapedDayofyear                                                       311
# calendar_last_scrapedIs_month_end                                                  False
# calendar_last_scrapedIs_month_start                                                False
# calendar_last_scrapedIs_quarter_end                                                False
# calendar_last_scrapedIs_quarter_start                                              False
# calendar_last_scrapedIs_year_end                                                   False
# calendar_last_scrapedIs_year_start                                                 False
# calendar_last_scrapedElapsed                                                  1541548800
# first_reviewYear                                                                    2018
# first_reviewMonth                                                                      7
# first_reviewWeek                                                                      27
# first_reviewDay                                                                        4
# first_reviewDayofweek                                                                  2
# first_reviewDayofyear                                                                185
# first_reviewIs_month_end                                                           False
# first_reviewIs_month_start                                                         False
# first_reviewIs_quarter_end                                                         False
# first_reviewIs_quarter_start                                                       False
# first_reviewIs_year_end                                                            False
# first_reviewIs_year_start                                                          False
# first_reviewElapsed                                                           1530662400
# last_reviewYear                                                                     2018
# last_reviewMonth                                                                      10
# last_reviewWeek                                                                       40
# last_reviewDay                                                                         1
# last_reviewDayofweek                                                                   0
# last_reviewDayofyear                                                                 274
# last_reviewIs_month_end                                                            False
# last_reviewIs_month_start                                                           True
# last_reviewIs_quarter_end                                                          False
# last_reviewIs_quarter_start                                                         True
# last_reviewIs_year_end                                                             False
# last_reviewIs_year_start                                                           False
# last_reviewElapsed                                                            1538352000
#
# [156 rows x 2 columns]

# %%
merge_dfs(df, new_date_col_df).columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        ...
#        'last_reviewDay', 'last_reviewDayofweek', 'last_reviewDayofyear',
#        'last_reviewIs_month_end', 'last_reviewIs_month_start',
#        'last_reviewIs_quarter_end', 'last_reviewIs_quarter_start',
#        'last_reviewIs_year_end', 'last_reviewIs_year_start',
#        'last_reviewElapsed'],
#       dtype='object', length=156)

# %%
new_df = merge_dfs(df, new_date_col_df)

# %% [markdown]
# We can confirm that the `new_df` has fewer `object_feature` columns than the original.

# %%
# new_df = new_df.drop(columns = remaining_date_features)
len(find_object_features(new_df))
# Out:
# 57

# %%
len(find_object_features(df))
# Out:
# 62

# %% [markdown]
# Even though our `new_df` has more features.

# %%
len(new_df.columns)
# Out:
# 156

# %% [markdown]
# ### Working with Trickier Dates

# %% [markdown]
# Sometimes we'll have have some features that represents a date, but is worded as text.  For example, the text '6 years ago' could be translated into a date.  Let's write a function that finds this features with this text.  And also write functions to coerce this data into the proper format.

# %%
def contains_time_ago(column):
    regex_string = (r'^\d.*ago$')
    return column.str.contains(regex_string).any()

# %%
def find_time_ago_features(df):
    series_contains_time_ago = df.apply(contains_time_ago)
    return series_contains_time_ago.index[series_contains_time_ago.values]

# %%
find_time_ago_features(df)
# Out:
# Index(['calendar_updated'], dtype='object')

# %%
from date_lib import get_past_date

# %%
calendar_updated = df.calendar_updated.apply(get_past_date).astype('datetime64[ns]')

# %%
calendar_updated.dtypes
# Out:
# dtype('<M8[ns]')

# %%
calendar_updated[0:12]
# Out:
# 0    2019-05-04
# 1    2019-06-16
# 2    2019-07-28
# 3    2019-07-07
# 4    2019-08-01
# 5    2019-07-21
# 6    2019-08-04
# 7           NaT
# 8    2019-06-04
# 9    2019-07-28
# 10   2019-07-30
# 11   2019-08-02
# Name: calendar_updated, dtype: datetime64[ns]

# %% [markdown]
# Now we can replace our `calendar_updated` column.

# %% [markdown]
# ### Generating New Features

# %% [markdown]
# There are some additional features that we did not generate.  For example, subtracting date columns from another and also subtracting dates from additional key dates like holidays.  Finally, to be even more ambitious, we could match dates to past temperatures if we believe this would help our dataset.

# %% [markdown]
# ### Summary
