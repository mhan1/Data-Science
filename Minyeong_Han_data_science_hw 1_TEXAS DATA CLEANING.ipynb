# %% [markdown]
# # Cleaning Data: Intro to ETL

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lesson, we will see how to take a lot of extra data from an API and clean this data.  A fancy term for this is extract transform and load.  Now extract just means retreiving the data, which we know how to do via an API.  So nothing new.  And load means to save the data, which we'll show at the end.
#
# The transform part is more interesting.  In general, we transform the data because we generally get it in a weird format and we want to transform it into the format we want to make our lives easier.  We transform data in two steps: (1) Reduce the amount of data by throwing away unnecessary data.  And (2) coerce that remaining data into the correct format or datatype.
#
# We'll walk you through this process, but we expect you to complete the review material like looping through data on your own.
#
#
# We'll do this using the Texas Open Data Portal to explore restaurant revenue data. This information is available via the Texas's Open Data API, and their information on Mixed Beverage Receipts.  Let's get started.

# %% [markdown]
# ### 1. Extracting Our Data from an API

# %% [markdown]
# Now Max's Wine Dive is a restaurant with multiple locations in Texas.

# %% [markdown]
# <img src='./max-maps.png' width="50%">

# %% [markdown]
# Let's try to see what information we can find on the Max's by using the Texas's Open Data API.  Navigating to the [Mixed Beverage Receipts](https://dev.socrata.com/foundry/data.texas.gov/naix-2893) data we see that we can search for specific restaurants using the `location_name` parameter.  Let's do that below

# %%
url = "https://data.texas.gov/resource/naix-2893.json?location_name=MAX%27S%20WINE%20DIVE"

# %% [markdown]
# Use the url above to make a request to the API, and store the json results as `restaurant_receipts`.

# %%
import requests
response = requests.get(url)
restaurant_receipts = response.json()

# %%
len(restaurant_receipts)
# 61
# Out:
# 61

# %%
restaurant_receipts
# Out:
# [{'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#   'liquor_receipts': '18265',
#   'wine_receipts': '71497',
#   'beer_receipts': '10606',
#   'cover_charge_receipts': '0',
#   'total_receipts': '100368'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-10-31T00:00:00.000',
#   'liquor_receipts': '24237',
#   'wine_receipts': '68943',
#   'beer_receipts': '11150',
#   'cover_charge_receipts': '0',
#   'total_receipts': '104330'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-06-30T00:00:00.000',
#   'liquor_receipts': '15836',
#   'wine_receipts': '49834',
#   'beer_receipts': '7991',
#   'cover_charge_receipts': '0',
#   'total_receipts': '73661'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-02-28T00:00:00.000',
#   'liquor_receipts': '30605',
#   'wine_receipts': '66099',
#   'beer_receipts': '11775',
#   'cover_charge_receipts': '0',
#   'total_receipts': '108479'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-04-30T00:00:00.000',
#   'liquor_receipts': '24460',
#   'wine_receipts': '69486',
#   'beer_receipts': '10327',
#   'cover_charge_receipts': '0',
#   'total_receipts': '104273'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-01-31T00:00:00.000',
#   'liquor_receipts': '22131',
#   'wine_receipts': '75125',
#   'beer_receipts': '12738',
#   'cover_charge_receipts': '0',
#   'total_receipts': '109994'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-06-30T00:00:00.000',
#   'liquor_receipts': '13841',
#   'wine_receipts': '50121',
#   'beer_receipts': '8175',
#   'cover_charge_receipts': '0',
#   'total_receipts': '72137'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-04-30T00:00:00.000',
#   'liquor_receipts': '29466',
#   'wine_receipts': '64297',
#   'beer_receipts': '10797',
#   'cover_charge_receipts': '0',
#   'total_receipts': '104560'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-02-28T00:00:00.000',
#   'liquor_receipts': '33615',
#   'wine_receipts': '72405',
#   'beer_receipts': '11665',
#   'cover_charge_receipts': '0',
#   'total_receipts': '117685'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-01-31T00:00:00.000',
#   'liquor_receipts': '22741',
#   'wine_receipts': '59152',
#   'beer_receipts': '11948',
#   'cover_charge_receipts': '0',
#   'total_receipts': '93841'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-10-31T00:00:00.000',
#   'liquor_receipts': '19481',
#   'wine_receipts': '53645',
#   'beer_receipts': '9813',
#   'cover_charge_receipts': '0',
#   'total_receipts': '82939'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-05-31T00:00:00.000',
#   'liquor_receipts': '20551',
#   'wine_receipts': '58665',
#   'beer_receipts': '12066',
#   'cover_charge_receipts': '0',
#   'total_receipts': '91282'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'liquor_receipts': '43646',
#   'wine_receipts': '75418',
#   'beer_receipts': '12326',
#   'cover_charge_receipts': '0',
#   'total_receipts': '131390'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-06-30T00:00:00.000',
#   'liquor_receipts': '10175',
#   'wine_receipts': '57429',
#   'beer_receipts': '8592',
#   'cover_charge_receipts': '0',
#   'total_receipts': '76196'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'liquor_receipts': '17373',
#   'wine_receipts': '42582',
#   'beer_receipts': '6769',
#   'cover_charge_receipts': '0',
#   'total_receipts': '66724'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-11-30T00:00:00.000',
#   'liquor_receipts': '19974',
#   'wine_receipts': '62897',
#   'beer_receipts': '9757',
#   'cover_charge_receipts': '0',
#   'total_receipts': '92628'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-07-31T00:00:00.000',
#   'liquor_receipts': '13016',
#   'wine_receipts': '70485',
#   'beer_receipts': '11735',
#   'cover_charge_receipts': '0',
#   'total_receipts': '95236'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-09-30T00:00:00.000',
#   'liquor_receipts': '21031',
#   'wine_receipts': '60588',
#   'beer_receipts': '8276',
#   'cover_charge_receipts': '0',
#   'total_receipts': '89895'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-12-31T00:00:00.000',
#   'liquor_receipts': '27765',
#   'wine_receipts': '63604',
#   'beer_receipts': '9494',
#   'cover_charge_receipts': '0',
#   'total_receipts': '100863'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-07-31T00:00:00.000',
#   'liquor_receipts': '14530',
#   'wine_receipts': '47226',
#   'beer_receipts': '7721',
#   'cover_charge_receipts': '0',
#   'total_receipts': '69477'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-11-30T00:00:00.000',
#   'liquor_receipts': '14818',
#   'wine_receipts': '53997',
#   'beer_receipts': '6485',
#   'cover_charge_receipts': '0',
#   'total_receipts': '75300'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-08-31T00:00:00.000',
#   'liquor_receipts': '24370',
#   'wine_receipts': '68460',
#   'beer_receipts': '12670',
#   'cover_charge_receipts': '0',
#   'total_receipts': '105500'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-09-30T00:00:00.000',
#   'liquor_receipts': '24072',
#   'wine_receipts': '63102',
#   'beer_receipts': '9009',
#   'cover_charge_receipts': '0',
#   'total_receipts': '96183'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-08-31T00:00:00.000',
#   'liquor_receipts': '18759',
#   'wine_receipts': '59482',
#   'beer_receipts': '11138',
#   'cover_charge_receipts': '0',
#   'total_receipts': '89379'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-03-31T00:00:00.000',
#   'liquor_receipts': '32317',
#   'wine_receipts': '76907',
#   'beer_receipts': '14074',
#   'cover_charge_receipts': '0',
#   'total_receipts': '123298'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-03-31T00:00:00.000',
#   'liquor_receipts': '28062',
#   'wine_receipts': '77831',
#   'beer_receipts': '14155',
#   'cover_charge_receipts': '0',
#   'total_receipts': '120048'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-05-31T00:00:00.000',
#   'liquor_receipts': '25324',
#   'wine_receipts': '67524',
#   'beer_receipts': '12250',
#   'cover_charge_receipts': '0',
#   'total_receipts': '105098'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2018-07-31T00:00:00.000',
#   'liquor_receipts': '13289',
#   'wine_receipts': '46627',
#   'beer_receipts': '6700',
#   'cover_charge_receipts': '0',
#   'total_receipts': '66616'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-12-31T00:00:00.000',
#   'liquor_receipts': '28355',
#   'wine_receipts': '70958',
#   'beer_receipts': '10728',
#   'cover_charge_receipts': '0',
#   'total_receipts': '110041'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-05-31T00:00:00.000',
#   'liquor_receipts': '372',
#   'wine_receipts': '48521',
#   'beer_receipts': '7201',
#   'cover_charge_receipts': '0',
#   'total_receipts': '56094'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-11-30T00:00:00.000',
#   'liquor_receipts': '22810',
#   'wine_receipts': '60040',
#   'beer_receipts': '7926',
#   'cover_charge_receipts': '0',
#   'total_receipts': '90776'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-10-31T00:00:00.000',
#   'liquor_receipts': '23957',
#   'wine_receipts': '59644',
#   'beer_receipts': '10021',
#   'cover_charge_receipts': '0',
#   'total_receipts': '93622'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'liquor_receipts': '12257',
#   'wine_receipts': '41093',
#   'beer_receipts': '2832',
#   'cover_charge_receipts': '0',
#   'total_receipts': '56182'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'liquor_receipts': '1626',
#   'wine_receipts': '7275',
#   'beer_receipts': '499',
#   'cover_charge_receipts': '0',
#   'total_receipts': '9400'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-06-30T00:00:00.000',
#   'liquor_receipts': '12507',
#   'wine_receipts': '35378',
#   'beer_receipts': '2689',
#   'cover_charge_receipts': '0',
#   'total_receipts': '50574'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-08-31T00:00:00.000',
#   'liquor_receipts': '10488',
#   'wine_receipts': '37686',
#   'beer_receipts': '2131',
#   'cover_charge_receipts': '0',
#   'total_receipts': '50305'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-09-30T00:00:00.000',
#   'liquor_receipts': '1330',
#   'wine_receipts': '60130',
#   'beer_receipts': '5149',
#   'cover_charge_receipts': '0',
#   'total_receipts': '66609'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2019-01-31T00:00:00.000',
#   'liquor_receipts': '30153',
#   'wine_receipts': '60014',
#   'beer_receipts': '14065',
#   'cover_charge_receipts': '0',
#   'total_receipts': '104232'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-06-30T00:00:00.000',
#   'liquor_receipts': '9902',
#   'wine_receipts': '27605',
#   'beer_receipts': '2028',
#   'cover_charge_receipts': '0',
#   'total_receipts': '39535'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-02-28T00:00:00.000',
#   'liquor_receipts': '10783',
#   'wine_receipts': '30290',
#   'beer_receipts': '2021',
#   'cover_charge_receipts': '0',
#   'total_receipts': '43094'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2019-02-28T00:00:00.000',
#   'liquor_receipts': '21522',
#   'wine_receipts': '65722',
#   'beer_receipts': '11869',
#   'cover_charge_receipts': '0',
#   'total_receipts': '99113'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-05-31T00:00:00.000',
#   'liquor_receipts': '8244',
#   'wine_receipts': '25309',
#   'beer_receipts': '1350',
#   'cover_charge_receipts': '0',
#   'total_receipts': '34903'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-11-30T00:00:00.000',
#   'liquor_receipts': '8246',
#   'wine_receipts': '31261',
#   'beer_receipts': '1547',
#   'cover_charge_receipts': '0',
#   'total_receipts': '41054'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-07-31T00:00:00.000',
#   'liquor_receipts': '9874',
#   'wine_receipts': '39734',
#   'beer_receipts': '2099',
#   'cover_charge_receipts': '0',
#   'total_receipts': '51707'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-07-31T00:00:00.000',
#   'liquor_receipts': '8575',
#   'wine_receipts': '28829',
#   'beer_receipts': '2223',
#   'cover_charge_receipts': '0',
#   'total_receipts': '39627'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-05-31T00:00:00.000',
#   'liquor_receipts': '10480',
#   'wine_receipts': '35828',
#   'beer_receipts': '1931',
#   'cover_charge_receipts': '0',
#   'total_receipts': '48239'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#   'liquor_receipts': '10275',
#   'wine_receipts': '33243',
#   'beer_receipts': '2072',
#   'cover_charge_receipts': '0',
#   'total_receipts': '45590'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-01-31T00:00:00.000',
#   'liquor_receipts': '9600',
#   'wine_receipts': '38226',
#   'beer_receipts': '2139',
#   'cover_charge_receipts': '0',
#   'total_receipts': '49965'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-08-31T00:00:00.000',
#   'liquor_receipts': '0',
#   'wine_receipts': '0',
#   'beer_receipts': '0',
#   'cover_charge_receipts': '0',
#   'total_receipts': '0'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2019-03-31T00:00:00.000',
#   'liquor_receipts': '31888',
#   'wine_receipts': '67469',
#   'beer_receipts': '13206',
#   'cover_charge_receipts': '0',
#   'total_receipts': '112563'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-04-30T00:00:00.000',
#   'liquor_receipts': '12253',
#   'wine_receipts': '36620',
#   'beer_receipts': '2557',
#   'cover_charge_receipts': '0',
#   'total_receipts': '51430'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-03-31T00:00:00.000',
#   'liquor_receipts': '12392',
#   'wine_receipts': '30158',
#   'beer_receipts': '1864',
#   'cover_charge_receipts': '0',
#   'total_receipts': '44414'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-11-30T00:00:00.000',
#   'liquor_receipts': '13469',
#   'wine_receipts': '53723',
#   'beer_receipts': '2472',
#   'cover_charge_receipts': '0',
#   'total_receipts': '69664'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-01-31T00:00:00.000',
#   'liquor_receipts': '16684',
#   'wine_receipts': '64586',
#   'beer_receipts': '3451',
#   'cover_charge_receipts': '0',
#   'total_receipts': '84721'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-12-31T00:00:00.000',
#   'liquor_receipts': '15964',
#   'wine_receipts': '52645',
#   'beer_receipts': '3629',
#   'cover_charge_receipts': '0',
#   'total_receipts': '72238'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-04-30T00:00:00.000',
#   'liquor_receipts': '10467',
#   'wine_receipts': '29169',
#   'beer_receipts': '1757',
#   'cover_charge_receipts': '0',
#   'total_receipts': '41393'},
#  {'taxpayer_number': '12727298569',
#   'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 255',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '207 SAN JACINTO BLVD STE 200',
#   'location_city': 'AUSTIN',
#   'location_state': 'TX',
#   'location_zip': '78701',
#   'location_county': '227',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB944126',
#   'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2019-04-30T00:00:00.000',
#   'liquor_receipts': '20241',
#   'wine_receipts': '42388',
#   'beer_receipts': '6946',
#   'cover_charge_receipts': '0',
#   'total_receipts': '69575'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-02-29T00:00:00.000',
#   'liquor_receipts': '14970',
#   'wine_receipts': '51492',
#   'beer_receipts': '2762',
#   'cover_charge_receipts': '0',
#   'total_receipts': '69224'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-10-31T00:00:00.000',
#   'liquor_receipts': '8525',
#   'wine_receipts': '32009',
#   'beer_receipts': '1646',
#   'cover_charge_receipts': '0',
#   'total_receipts': '42180'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-03-31T00:00:00.000',
#   'liquor_receipts': '11706',
#   'wine_receipts': '44309',
#   'beer_receipts': '2682',
#   'cover_charge_receipts': '0',
#   'total_receipts': '58697'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-10-31T00:00:00.000',
#   'liquor_receipts': '12571',
#   'wine_receipts': '51211',
#   'beer_receipts': '3266',
#   'cover_charge_receipts': '0',
#   'total_receipts': '67048'}]

# %% [markdown]
# ### 2. Understanding What's Returned

# %% [markdown]
# We see that we get back a list of 61 entries.  Let's see what's in these entries by taking a closer look at the first entry.

# %%
first_receipt = restaurant_receipts[0]
first_receipt

# {'beer_receipts': '10606',
#  'cover_charge_receipts': '0',
#  'inside_outside_city_limits_code_y_n': 'Y',
#  'liquor_receipts': '18265',
#  'location_address': '207 SAN JACINTO BLVD STE 200',
#  'location_city': 'AUSTIN',
#  'location_county': '227',
#  'location_name': "MAX'S WINE DIVE",
#  'location_number': '1',
#  'location_state': 'TX',
#  'location_zip': '78701',
#  'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#  'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#  'tabc_permit_number': 'MB944126',
#  'taxpayer_address': '7026 OLD KATY RD STE 255',
#  'taxpayer_city': 'HOUSTON',
#  'taxpayer_county': '101',
#  'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#  'taxpayer_number': '12727298569',
#  'taxpayer_state': 'TX',
#  'taxpayer_zip': '77024',
#  'total_receipts': '100368',
#  'wine_receipts': '71497'}
# Out:
# {'taxpayer_number': '12727298569',
#  'taxpayer_name': 'MWD AUSTIN DOWNTOWN, LLC',
#  'taxpayer_address': '7026 OLD KATY RD STE 255',
#  'taxpayer_city': 'HOUSTON',
#  'taxpayer_state': 'TX',
#  'taxpayer_zip': '77024',
#  'taxpayer_county': '101',
#  'location_number': '1',
#  'location_name': "MAX'S WINE DIVE",
#  'location_address': '207 SAN JACINTO BLVD STE 200',
#  'location_city': 'AUSTIN',
#  'location_state': 'TX',
#  'location_zip': '78701',
#  'location_county': '227',
#  'inside_outside_city_limits_code_y_n': 'Y',
#  'tabc_permit_number': 'MB944126',
#  'responsibility_begin_date_yyyymmdd': '2016-05-13T00:00:00.000',
#  'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#  'liquor_receipts': '18265',
#  'wine_receipts': '71497',
#  'beer_receipts': '10606',
#  'cover_charge_receipts': '0',
#  'total_receipts': '100368'}

# %% [markdown]
# Now looking at the first entry, it looks like the restaurant reports total alcohol revenue, as well as revenue for beer, wine and liquor.  It looks like from the `location_number` and `location_address` attributes that this information is for a single Max's Wine location.  And the `obligation_end_date` and `responsibility_begin_date` perhaps could be the time period.
#
# We still have some questions though.  Are we sure we should be using `location_address` instead of `taxpayer_address`?  Are there multiple addresses in the data?  One way of getting a better sense of the data is to see the range of information that could be interesting to us.  So let's do the following.  Let's get a list of just the `location_address` and place it in the `location_addresses` list.  Then we'll find the distinct values in the list.

# %%
restaurant_receipts[0].keys()
# Out:
# dict_keys(['taxpayer_number', 'taxpayer_name', 'taxpayer_address', 'taxpayer_city', 'taxpayer_state', 'taxpayer_zip', 'taxpayer_county', 'location_number', 'location_name', 'location_address', 'location_city', 'location_state', 'location_zip', 'location_county', 'inside_outside_city_limits_code_y_n', 'tabc_permit_number', 'responsibility_begin_date_yyyymmdd', 'obligation_end_date_yyyymmdd', 'liquor_receipts', 'wine_receipts', 'beer_receipts', 'cover_charge_receipts', 'total_receipts'])

# %%
restaurant_receipts[0]['location_address']
# Out:
# '207 SAN JACINTO BLVD STE 200'

# %%
[d['location_address'] for d in restaurant_receipts]
# Out:
# ['207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '207 SAN JACINTO BLVD STE 200',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '207 SAN JACINTO BLVD STE 200',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '207 SAN JACINTO BLVD STE 200',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '207 SAN JACINTO BLVD STE 200',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '207 SAN JACINTO BLVD STE 200',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100',
#  '3600 MCKINNEY AVE STE 100']

# %%
location_addresses = [d['location_address'] for d in restaurant_receipts]

set(location_addresses)
# {'207 SAN JACINTO BLVD STE 200', '3600 MCKINNEY AVE STE 100'}
# Out:
# {'207 SAN JACINTO BLVD STE 200', '3600 MCKINNEY AVE STE 100'}

# %% [markdown]
# Ok, so we do see two addresses listed here.  A search on Google confirms that this matches location addresses that we have.

# %% [markdown]
# ### 3. Reduce Our Data (Transform)

# %% [markdown]
# #### A. Reduce the number of items

# %% [markdown]
# Now, as we know one of the unwieldy things about APIs is the amount of information that's returned.  So let's work on scoping the amount of information we need to work with.  The first thing we can do is to only focus in on one restaurant, the `3600 MCKINNEY AVE STE 100` address.  Select only those restaurants with the address '3600 MCKINNEY AVE STE 100' and place them in a list called `dallas_maxs`, as this location is in Dallas.  Use Python to accomplish this.

# %%
[d for d in restaurant_receipts if d['location_address'] == '3600 MCKINNEY AVE STE 100']
# Out:
# [{'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'liquor_receipts': '12257',
#   'wine_receipts': '41093',
#   'beer_receipts': '2832',
#   'cover_charge_receipts': '0',
#   'total_receipts': '56182'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'liquor_receipts': '1626',
#   'wine_receipts': '7275',
#   'beer_receipts': '499',
#   'cover_charge_receipts': '0',
#   'total_receipts': '9400'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-06-30T00:00:00.000',
#   'liquor_receipts': '12507',
#   'wine_receipts': '35378',
#   'beer_receipts': '2689',
#   'cover_charge_receipts': '0',
#   'total_receipts': '50574'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-08-31T00:00:00.000',
#   'liquor_receipts': '10488',
#   'wine_receipts': '37686',
#   'beer_receipts': '2131',
#   'cover_charge_receipts': '0',
#   'total_receipts': '50305'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-09-30T00:00:00.000',
#   'liquor_receipts': '1330',
#   'wine_receipts': '60130',
#   'beer_receipts': '5149',
#   'cover_charge_receipts': '0',
#   'total_receipts': '66609'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-06-30T00:00:00.000',
#   'liquor_receipts': '9902',
#   'wine_receipts': '27605',
#   'beer_receipts': '2028',
#   'cover_charge_receipts': '0',
#   'total_receipts': '39535'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-02-28T00:00:00.000',
#   'liquor_receipts': '10783',
#   'wine_receipts': '30290',
#   'beer_receipts': '2021',
#   'cover_charge_receipts': '0',
#   'total_receipts': '43094'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-05-31T00:00:00.000',
#   'liquor_receipts': '8244',
#   'wine_receipts': '25309',
#   'beer_receipts': '1350',
#   'cover_charge_receipts': '0',
#   'total_receipts': '34903'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-11-30T00:00:00.000',
#   'liquor_receipts': '8246',
#   'wine_receipts': '31261',
#   'beer_receipts': '1547',
#   'cover_charge_receipts': '0',
#   'total_receipts': '41054'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-07-31T00:00:00.000',
#   'liquor_receipts': '9874',
#   'wine_receipts': '39734',
#   'beer_receipts': '2099',
#   'cover_charge_receipts': '0',
#   'total_receipts': '51707'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-07-31T00:00:00.000',
#   'liquor_receipts': '8575',
#   'wine_receipts': '28829',
#   'beer_receipts': '2223',
#   'cover_charge_receipts': '0',
#   'total_receipts': '39627'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-05-31T00:00:00.000',
#   'liquor_receipts': '10480',
#   'wine_receipts': '35828',
#   'beer_receipts': '1931',
#   'cover_charge_receipts': '0',
#   'total_receipts': '48239'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#   'liquor_receipts': '10275',
#   'wine_receipts': '33243',
#   'beer_receipts': '2072',
#   'cover_charge_receipts': '0',
#   'total_receipts': '45590'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-01-31T00:00:00.000',
#   'liquor_receipts': '9600',
#   'wine_receipts': '38226',
#   'beer_receipts': '2139',
#   'cover_charge_receipts': '0',
#   'total_receipts': '49965'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-08-31T00:00:00.000',
#   'liquor_receipts': '0',
#   'wine_receipts': '0',
#   'beer_receipts': '0',
#   'cover_charge_receipts': '0',
#   'total_receipts': '0'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-04-30T00:00:00.000',
#   'liquor_receipts': '12253',
#   'wine_receipts': '36620',
#   'beer_receipts': '2557',
#   'cover_charge_receipts': '0',
#   'total_receipts': '51430'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-03-31T00:00:00.000',
#   'liquor_receipts': '12392',
#   'wine_receipts': '30158',
#   'beer_receipts': '1864',
#   'cover_charge_receipts': '0',
#   'total_receipts': '44414'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-11-30T00:00:00.000',
#   'liquor_receipts': '13469',
#   'wine_receipts': '53723',
#   'beer_receipts': '2472',
#   'cover_charge_receipts': '0',
#   'total_receipts': '69664'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-01-31T00:00:00.000',
#   'liquor_receipts': '16684',
#   'wine_receipts': '64586',
#   'beer_receipts': '3451',
#   'cover_charge_receipts': '0',
#   'total_receipts': '84721'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-12-31T00:00:00.000',
#   'liquor_receipts': '15964',
#   'wine_receipts': '52645',
#   'beer_receipts': '3629',
#   'cover_charge_receipts': '0',
#   'total_receipts': '72238'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-04-30T00:00:00.000',
#   'liquor_receipts': '10467',
#   'wine_receipts': '29169',
#   'beer_receipts': '1757',
#   'cover_charge_receipts': '0',
#   'total_receipts': '41393'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-02-29T00:00:00.000',
#   'liquor_receipts': '14970',
#   'wine_receipts': '51492',
#   'beer_receipts': '2762',
#   'cover_charge_receipts': '0',
#   'total_receipts': '69224'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-10-31T00:00:00.000',
#   'liquor_receipts': '8525',
#   'wine_receipts': '32009',
#   'beer_receipts': '1646',
#   'cover_charge_receipts': '0',
#   'total_receipts': '42180'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-03-31T00:00:00.000',
#   'liquor_receipts': '11706',
#   'wine_receipts': '44309',
#   'beer_receipts': '2682',
#   'cover_charge_receipts': '0',
#   'total_receipts': '58697'},
#  {'taxpayer_number': '32046798537',
#   'taxpayer_name': 'MWD DALLAS UPTOWN, LLC',
#   'taxpayer_address': '7026 OLD KATY RD STE 250',
#   'taxpayer_city': 'HOUSTON',
#   'taxpayer_state': 'TX',
#   'taxpayer_zip': '77024',
#   'taxpayer_county': '101',
#   'location_number': '1',
#   'location_name': "MAX'S WINE DIVE",
#   'location_address': '3600 MCKINNEY AVE STE 100',
#   'location_city': 'DALLAS',
#   'location_state': 'TX',
#   'location_zip': '75204',
#   'location_county': '57',
#   'inside_outside_city_limits_code_y_n': 'Y',
#   'tabc_permit_number': 'MB917035',
#   'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'responsibility_end_date_yyyymmdd': '2017-08-21T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-10-31T00:00:00.000',
#   'liquor_receipts': '12571',
#   'wine_receipts': '51211',
#   'beer_receipts': '3266',
#   'cover_charge_receipts': '0',
#   'total_receipts': '67048'}]

# %%
dallas_maxs = [d for d in restaurant_receipts if d['location_address'] == '3600 MCKINNEY AVE STE 100']


dallas_maxs[0]['location_address']
# '3600 MCKINNEY AVE STE 100'
# Out:
# '3600 MCKINNEY AVE STE 100'

# %%
len(dallas_maxs)
# 25
# Out:
# 25

# %% [markdown]
# #### B. Reduce the amount of data per item

# %% [markdown]
# Ok, so now that we have cut the number of items in half, let's also limit the amount of information in each item.  Let's start by remembering what information contained in each dictionary.  An easy way to do so is to use the `keys` method on our dictionary.

# %%
first_dallas_receipt = dallas_maxs[0]
first_dallas_receipt.keys()
# Out:
# dict_keys(['taxpayer_number', 'taxpayer_name', 'taxpayer_address', 'taxpayer_city', 'taxpayer_state', 'taxpayer_zip', 'taxpayer_county', 'location_number', 'location_name', 'location_address', 'location_city', 'location_state', 'location_zip', 'location_county', 'inside_outside_city_limits_code_y_n', 'tabc_permit_number', 'responsibility_begin_date_yyyymmdd', 'responsibility_end_date_yyyymmdd', 'obligation_end_date_yyyymmdd', 'liquor_receipts', 'wine_receipts', 'beer_receipts', 'cover_charge_receipts', 'total_receipts'])

# %% [markdown]
# Ok, so we can see that a lot of information is here.  Let's reduce our information by only including the `total_receipts`, the `responsibility_begin_date_yyyymmdd` and the `obligation_end_date_yyyymmdd`.

# %%
keys = ("total_receipts", "responsibility_begin_date_yyyymmdd", "obligation_end_date_yyyymmdd")
[{i:elem[i] for i in elem if i in keys} for elem in dallas_maxs]
# Out:
# [{'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'total_receipts': '56182'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'total_receipts': '9400'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-06-30T00:00:00.000',
#   'total_receipts': '50574'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-08-31T00:00:00.000',
#   'total_receipts': '50305'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-09-30T00:00:00.000',
#   'total_receipts': '66609'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-06-30T00:00:00.000',
#   'total_receipts': '39535'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-02-28T00:00:00.000',
#   'total_receipts': '43094'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-05-31T00:00:00.000',
#   'total_receipts': '34903'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-11-30T00:00:00.000',
#   'total_receipts': '41054'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-07-31T00:00:00.000',
#   'total_receipts': '51707'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-07-31T00:00:00.000',
#   'total_receipts': '39627'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-05-31T00:00:00.000',
#   'total_receipts': '48239'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#   'total_receipts': '45590'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-01-31T00:00:00.000',
#   'total_receipts': '49965'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-08-31T00:00:00.000',
#   'total_receipts': '0'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-04-30T00:00:00.000',
#   'total_receipts': '51430'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-03-31T00:00:00.000',
#   'total_receipts': '44414'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-11-30T00:00:00.000',
#   'total_receipts': '69664'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-01-31T00:00:00.000',
#   'total_receipts': '84721'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-12-31T00:00:00.000',
#   'total_receipts': '72238'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-04-30T00:00:00.000',
#   'total_receipts': '41393'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-02-29T00:00:00.000',
#   'total_receipts': '69224'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-10-31T00:00:00.000',
#   'total_receipts': '42180'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-03-31T00:00:00.000',
#   'total_receipts': '58697'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-10-31T00:00:00.000',
#   'total_receipts': '67048'}]

# %%
keys = ("total_receipts", "responsibility_begin_date_yyyymmdd", "obligation_end_date_yyyymmdd")

restaurant_revenues = [{i:elem[i] for i in elem if i in keys} for elem in dallas_maxs]
len(restaurant_revenues)
# 25
# Out:
# 25

# %%
restaurant_revenues
# Out:
# [{'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'total_receipts': '56182'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'total_receipts': '9400'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-06-30T00:00:00.000',
#   'total_receipts': '50574'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-08-31T00:00:00.000',
#   'total_receipts': '50305'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-09-30T00:00:00.000',
#   'total_receipts': '66609'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-06-30T00:00:00.000',
#   'total_receipts': '39535'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-02-28T00:00:00.000',
#   'total_receipts': '43094'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-05-31T00:00:00.000',
#   'total_receipts': '34903'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-11-30T00:00:00.000',
#   'total_receipts': '41054'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-07-31T00:00:00.000',
#   'total_receipts': '51707'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-07-31T00:00:00.000',
#   'total_receipts': '39627'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-05-31T00:00:00.000',
#   'total_receipts': '48239'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#   'total_receipts': '45590'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-01-31T00:00:00.000',
#   'total_receipts': '49965'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-08-31T00:00:00.000',
#   'total_receipts': '0'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-04-30T00:00:00.000',
#   'total_receipts': '51430'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-03-31T00:00:00.000',
#   'total_receipts': '44414'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-11-30T00:00:00.000',
#   'total_receipts': '69664'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-01-31T00:00:00.000',
#   'total_receipts': '84721'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-12-31T00:00:00.000',
#   'total_receipts': '72238'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-04-30T00:00:00.000',
#   'total_receipts': '41393'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-02-29T00:00:00.000',
#   'total_receipts': '69224'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-10-31T00:00:00.000',
#   'total_receipts': '42180'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-03-31T00:00:00.000',
#   'total_receipts': '58697'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2015-10-31T00:00:00.000',
#   'total_receipts': '67048'}]

# %%
restaurant_revenues[0:2]

# [{'total_receipts': '56182',
#   'begin_date': '2015-08-11T00:00:00.000',
#   'end_date': '2016-12-31T00:00:00.000'},
#  {'total_receipts': '9400',
#   'begin_date': '2015-08-11T00:00:00.000',
#   'end_date': '2017-08-31T00:00:00.000'}]
# Out:
# [{'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'total_receipts': '56182'},
#  {'responsibility_begin_date_yyyymmdd': '2015-08-11T00:00:00.000',
#   'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'total_receipts': '9400'}]

# %% [markdown]
# Now looking at the first two elements we see that the end date seems to proceed monthly but that `begin_date` is always May 13 2016.  It seems like this just marks the first time that Max's needed to submit information.  We don't need to know this, so let's remove it from our list.

# %%
[{i:elem[i] for i in elem if i!="responsibility_begin_date_yyyymmdd"} for elem in restaurant_revenues]
# Out:
# [{'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'total_receipts': '56182'},
#  {'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'total_receipts': '9400'},
#  {'obligation_end_date_yyyymmdd': '2016-06-30T00:00:00.000',
#   'total_receipts': '50574'},
#  {'obligation_end_date_yyyymmdd': '2016-08-31T00:00:00.000',
#   'total_receipts': '50305'},
#  {'obligation_end_date_yyyymmdd': '2015-09-30T00:00:00.000',
#   'total_receipts': '66609'},
#  {'obligation_end_date_yyyymmdd': '2017-06-30T00:00:00.000',
#   'total_receipts': '39535'},
#  {'obligation_end_date_yyyymmdd': '2017-02-28T00:00:00.000',
#   'total_receipts': '43094'},
#  {'obligation_end_date_yyyymmdd': '2017-05-31T00:00:00.000',
#   'total_receipts': '34903'},
#  {'obligation_end_date_yyyymmdd': '2016-11-30T00:00:00.000',
#   'total_receipts': '41054'},
#  {'obligation_end_date_yyyymmdd': '2016-07-31T00:00:00.000',
#   'total_receipts': '51707'},
#  {'obligation_end_date_yyyymmdd': '2017-07-31T00:00:00.000',
#   'total_receipts': '39627'},
#  {'obligation_end_date_yyyymmdd': '2016-05-31T00:00:00.000',
#   'total_receipts': '48239'},
#  {'obligation_end_date_yyyymmdd': '2016-09-30T00:00:00.000',
#   'total_receipts': '45590'},
#  {'obligation_end_date_yyyymmdd': '2017-01-31T00:00:00.000',
#   'total_receipts': '49965'},
#  {'obligation_end_date_yyyymmdd': '2015-08-31T00:00:00.000',
#   'total_receipts': '0'},
#  {'obligation_end_date_yyyymmdd': '2016-04-30T00:00:00.000',
#   'total_receipts': '51430'},
#  {'obligation_end_date_yyyymmdd': '2017-03-31T00:00:00.000',
#   'total_receipts': '44414'},
#  {'obligation_end_date_yyyymmdd': '2015-11-30T00:00:00.000',
#   'total_receipts': '69664'},
#  {'obligation_end_date_yyyymmdd': '2016-01-31T00:00:00.000',
#   'total_receipts': '84721'},
#  {'obligation_end_date_yyyymmdd': '2015-12-31T00:00:00.000',
#   'total_receipts': '72238'},
#  {'obligation_end_date_yyyymmdd': '2017-04-30T00:00:00.000',
#   'total_receipts': '41393'},
#  {'obligation_end_date_yyyymmdd': '2016-02-29T00:00:00.000',
#   'total_receipts': '69224'},
#  {'obligation_end_date_yyyymmdd': '2016-10-31T00:00:00.000',
#   'total_receipts': '42180'},
#  {'obligation_end_date_yyyymmdd': '2016-03-31T00:00:00.000',
#   'total_receipts': '58697'},
#  {'obligation_end_date_yyyymmdd': '2015-10-31T00:00:00.000',
#   'total_receipts': '67048'}]

# %%
revenues_by_date = [{i:elem[i] for i in elem if i!="responsibility_begin_date_yyyymmdd"} for elem in restaurant_revenues]

len(revenues_by_date)
# 25
# Out:
# 25

# %%
revenues_by_date[0:2]
# Out:
# [{'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#   'total_receipts': '56182'},
#  {'obligation_end_date_yyyymmdd': '2017-08-31T00:00:00.000',
#   'total_receipts': '9400'}]

# %% [markdown]
# ### 4.  Coerce the data (Still Transform)

# %% [markdown]
# Our final step will be to coerce our data to the correct format. We'd like total receipts to be an integer and we'd like the begin date to be of type `datetime`.
#
# This is a little tricky so let's do it with dictionary first object first.

# %%
first_rev_by_date = revenues_by_date[0]
first_rev_by_date
# Out:
# {'obligation_end_date_yyyymmdd': '2016-12-31T00:00:00.000',
#  'total_receipts': '56182'}

# %% [markdown]
# We can go from a string to an integer by using the `int` function.  The `int` function is called a constructor because it's used to construct integers.  We can use it so long as we pass in a string that can be changed to an integer.

# %%
int('33')
# Out:
# 33

# %%
int(first_rev_by_date['total_receipts'])
# Out:
# 56182

# %% [markdown]
# Ok, now let's coerce the string into a datetime.  First we ask the great oracle Google how we can [convert a string into a datetime](https://www.google.com/search?q=datetime+from+string+python&oq=datetime+from+st&aqs=chrome.0.0j69i57j0l4.2653j0j7&sourceid=chrome&ie=UTF-8).  Then we follow the directions in the search results. [One of those results](https://chrisalbon.com/python/basics/strings_to_datetime/) says we can convert with somthing like the following.

# %%
from datetime import datetime
start = '2011-01-03'
datetime.strptime(start, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %% [markdown]
# That gets us part of the way, but our date information includes information about minutes or seconds.  So we can either remove that ending data, or we can do some more searching on Google.  We go for the searching on Google and wind up with the following.

# %%
from datetime import datetime
end_date = first_rev_by_date['obligation_end_date_yyyymmdd']
datetime.strptime(end_date, '%Y-%m-%dT%H:%M:%S.%f')
# Out:
# datetime.datetime(2016, 12, 31, 0, 0)

# %% [markdown]
# Ok, now it's that we were able to accomplish this for the attributes of one dictionary, let's use a loop to coerce each dictionary in `revenues_by_date`.

# %%
from datetime import datetime
formatted_revenues = []
for revenue in revenues_by_date:
    total = int(revenue['total_receipts'])
    revenue = {
        'total_receipts': total,
        'end_date': revenue['obligation_end_date_yyyymmdd'],
    }
    formatted_revenues.append(revenue)
formatted_revenues[0:2]
# Out:
# [{'total_receipts': 56182, 'end_date': '2016-12-31T00:00:00.000'},
#  {'total_receipts': 9400, 'end_date': '2017-08-31T00:00:00.000'}]

# %%
formatted_revenues
# Out:
# [{'total_receipts': 56182, 'end_date': '2016-12-31T00:00:00.000'},
#  {'total_receipts': 9400, 'end_date': '2017-08-31T00:00:00.000'},
#  {'total_receipts': 50574, 'end_date': '2016-06-30T00:00:00.000'},
#  {'total_receipts': 50305, 'end_date': '2016-08-31T00:00:00.000'},
#  {'total_receipts': 66609, 'end_date': '2015-09-30T00:00:00.000'},
#  {'total_receipts': 39535, 'end_date': '2017-06-30T00:00:00.000'},
#  {'total_receipts': 43094, 'end_date': '2017-02-28T00:00:00.000'},
#  {'total_receipts': 34903, 'end_date': '2017-05-31T00:00:00.000'},
#  {'total_receipts': 41054, 'end_date': '2016-11-30T00:00:00.000'},
#  {'total_receipts': 51707, 'end_date': '2016-07-31T00:00:00.000'},
#  {'total_receipts': 39627, 'end_date': '2017-07-31T00:00:00.000'},
#  {'total_receipts': 48239, 'end_date': '2016-05-31T00:00:00.000'},
#  {'total_receipts': 45590, 'end_date': '2016-09-30T00:00:00.000'},
#  {'total_receipts': 49965, 'end_date': '2017-01-31T00:00:00.000'},
#  {'total_receipts': 0, 'end_date': '2015-08-31T00:00:00.000'},
#  {'total_receipts': 51430, 'end_date': '2016-04-30T00:00:00.000'},
#  {'total_receipts': 44414, 'end_date': '2017-03-31T00:00:00.000'},
#  {'total_receipts': 69664, 'end_date': '2015-11-30T00:00:00.000'},
#  {'total_receipts': 84721, 'end_date': '2016-01-31T00:00:00.000'},
#  {'total_receipts': 72238, 'end_date': '2015-12-31T00:00:00.000'},
#  {'total_receipts': 41393, 'end_date': '2017-04-30T00:00:00.000'},
#  {'total_receipts': 69224, 'end_date': '2016-02-29T00:00:00.000'},
#  {'total_receipts': 42180, 'end_date': '2016-10-31T00:00:00.000'},
#  {'total_receipts': 58697, 'end_date': '2016-03-31T00:00:00.000'},
#  {'total_receipts': 67048, 'end_date': '2015-10-31T00:00:00.000'}]

# %%
len(formatted_revenues)
# Out:
# 25

# %%
type(formatted_revenues[0]['total_receipts'])
# Out:
# int

# %%
type(formatted_revenues[0]['end_date'])
# Out:
# str

# %% [markdown]
# ### 5. Store our data (Load)

# %% [markdown]
# Once we have our date in a good format.  Let's store that data so that we can use it in some future research.  The following code is slightly confusing, but it's also freely available on the Internet.  So let's use it to write our data to a file.

# %%
import json
with open('maxs_revenues.json', 'w') as filehandle:  
    json.dump(formatted_revenues, filehandle)

# %%
filehandle
# Out:
# <_io.TextIOWrapper name='maxs_revenues.json' mode='w' encoding='cp949'>

# %% [markdown]
# We can eaily check that we stored this data correctly by attempting to read that data.

# %%
with open('maxs_revenues.json') as json_file:  
    pulled_revenues = json.load(json_file)

# %%
pulled_revenues
# Out:
# [{'total_receipts': 56182, 'end_date': '2016-12-31T00:00:00.000'},
#  {'total_receipts': 9400, 'end_date': '2017-08-31T00:00:00.000'},
#  {'total_receipts': 50574, 'end_date': '2016-06-30T00:00:00.000'},
#  {'total_receipts': 50305, 'end_date': '2016-08-31T00:00:00.000'},
#  {'total_receipts': 66609, 'end_date': '2015-09-30T00:00:00.000'},
#  {'total_receipts': 39535, 'end_date': '2017-06-30T00:00:00.000'},
#  {'total_receipts': 43094, 'end_date': '2017-02-28T00:00:00.000'},
#  {'total_receipts': 34903, 'end_date': '2017-05-31T00:00:00.000'},
#  {'total_receipts': 41054, 'end_date': '2016-11-30T00:00:00.000'},
#  {'total_receipts': 51707, 'end_date': '2016-07-31T00:00:00.000'},
#  {'total_receipts': 39627, 'end_date': '2017-07-31T00:00:00.000'},
#  {'total_receipts': 48239, 'end_date': '2016-05-31T00:00:00.000'},
#  {'total_receipts': 45590, 'end_date': '2016-09-30T00:00:00.000'},
#  {'total_receipts': 49965, 'end_date': '2017-01-31T00:00:00.000'},
#  {'total_receipts': 0, 'end_date': '2015-08-31T00:00:00.000'},
#  {'total_receipts': 51430, 'end_date': '2016-04-30T00:00:00.000'},
#  {'total_receipts': 44414, 'end_date': '2017-03-31T00:00:00.000'},
#  {'total_receipts': 69664, 'end_date': '2015-11-30T00:00:00.000'},
#  {'total_receipts': 84721, 'end_date': '2016-01-31T00:00:00.000'},
#  {'total_receipts': 72238, 'end_date': '2015-12-31T00:00:00.000'},
#  {'total_receipts': 41393, 'end_date': '2017-04-30T00:00:00.000'},
#  {'total_receipts': 69224, 'end_date': '2016-02-29T00:00:00.000'},
#  {'total_receipts': 42180, 'end_date': '2016-10-31T00:00:00.000'},
#  {'total_receipts': 58697, 'end_date': '2016-03-31T00:00:00.000'},
#  {'total_receipts': 67048, 'end_date': '2015-10-31T00:00:00.000'}]

# %%
len(pulled_revenues)
# Out:
# 25

# %%
pulled_revenues[0:2]
# Out:
# [{'total_receipts': 56182, 'end_date': '2016-12-31T00:00:00.000'},
#  {'total_receipts': 9400, 'end_date': '2017-08-31T00:00:00.000'}]

# %% [markdown]
# Ok, looks good!

# %% [markdown]
# ### Summary

# %% [markdown]
# Ok congrats! We've now gone through the entire process of *extracting* our data from an API, *transforming* that data into a format that we want and then *loading data* into a file.  The trickiest part here is the transforming component.
#
# After first understanding our data by looking at what we retreived from the API, then we tried to reduce this data.  First we did this by reducing the number of entries as we only wanted data from one restaurant location.  Then we reduced the information in each entry by looking at all of the information included in the dictionary with the `keys` method and then looping through our data to only select the `key` `value` pairs that we would like. Finally, we coerced our data into a datatype and format that would be easiest for us to work with later on.
#
# This process is very useful.  The reason why is because we will likely want to access our data many times.  And we don't want to have to clean that data each time we do.  Instead, let's just clean it once, and then we can access that cleaned up, easier to work with data as much as we want.
